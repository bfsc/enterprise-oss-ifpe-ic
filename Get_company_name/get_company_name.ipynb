# %%
# Importa as bibliotecas
import pandas as pd
import numpy as np
import os
import json
import requests
import whois

# %%
# Carrega o DataSet
df = pd.read_csv(r"../Tabela_spinelli/enterprise_projects.txt", sep="\t", header=None)
df.columns = ['url', 'project_id', 'sdtc', 'mcpc', 'mcve', 'star_number', 'commit_count', 'files',
                'lines', 'pull_requests', 'most_recent_commit', 'committer_count', 'author_count',
                'dominant_domain', 'dominant_domain_commiter_commits', 'dominant_domain_author_commits',
                'dominant_domain_committers', 'dominant_domain_authors', 'cik', 'fg500', 'sec10k', 'sec20f',
                'project_name', 'owner_login', 'company_name', 'owner_company', 'license']
df
# Out:
#                                                      url  project_id sdtc  \
# 0                   https://github.com/ScottLogic/finput    63242591    t
# 1      https://github.com/Azure/azure-mobile-apps-cor...    31676975    t
# 2             https://github.com/bridgedotnet/Frameworks    18049778    t
# 3      https://github.com/makinacorpus/django-templat...       42543    f
# 4                        https://github.com/travis-ci/gh     6355545    f
# ...                                                  ...         ...  ...
# 17247                    https://github.com/rapid7/godap    34255643    f
# 17248      https://github.com/zendesk/zendesk_apps_tools     2274288    t
# 17249             https://github.com/cksystemsgroup/scal     2242312    t
# 17250            https://github.com/NeowayLabs/neosearch    16777887    f
# 17251             https://github.com/AdaCore/bb-runtimes    70649594    t
#
#       mcpc mcve  star_number  commit_count  files     lines  pull_requests  \
# 0        t    t           16           313    NaN       NaN             56
# 1        t    t           29            53   78.0   33715.0             22
# 2        f    f           38           353  413.0   62237.0             39
# 3        t    t           48            30   12.0    2154.0              3
# 4        t    f           22           163   72.0   21376.0             19
# ...    ...  ...          ...           ...    ...       ...            ...
# 17247    t    t           15            85   52.0    3332.0             10
# 17248    f    f           43          1462   72.0    4144.0            253
# 17249    f    f          106           490  161.0   22417.0             15
# 17250    t    t           30           237  112.0  113160.0             19
# 17251    f    f           23           260  869.0  166203.0              6
#
#        ... dominant_domain_authors        cik  fg500 sec10k  sec20f  \
# 0      ...                       3        NaN    NaN    NaN     NaN
# 1      ...                       4   789019.0      t      t       f
# 2      ...                       3        NaN    NaN    NaN     NaN
# 3      ...                       0        NaN    NaN    NaN     NaN
# 4      ...                       0        NaN    NaN    NaN     NaN
# ...    ...                     ...        ...    ...    ...     ...
# 17247  ...                       2  1560327.0      f      t       f
# 17248  ...                      25  1463172.0      f      t       f
# 17249  ...                       3        NaN    NaN    NaN     NaN
# 17250  ...                       5        NaN    NaN    NaN     NaN
# 17251  ...                      10        NaN    NaN    NaN     NaN
#
#                            project_name     owner_login  \
# 0                                finput      scottlogic
# 1      azure-mobile-apps-cordova-client           Azure
# 2                            Frameworks    bridgedotnet
# 3         django-templatetag-handlebars    makinacorpus
# 4                                    gh       travis-ci
# ...                                 ...             ...
# 17247                             godap          rapid7
# 17248                zendesk_apps_tools         zendesk
# 17249                              scal  cksystemsgroup
# 17250                         neosearch      NeowayLabs
# 17251                       bb-runtimes         AdaCore
#
#                 company_name  owner_company      license
# 0                        NaN            NaN          MIT
# 1      MICROSOFT CORPORATION            NaN   Apache-2.0
# 2                        NaN            NaN   Apache-2.0
# 3                        NaN            NaN     LGPL-3.0
# 4                        NaN            NaN          MIT
# ...                      ...            ...          ...
# 17247           RAPID7, INC.            NaN          MIT
# 17248          Zendesk, Inc.            NaN   Apache-2.0
# 17249                    NaN            NaN  NOASSERTION
# 17250                    NaN            NaN          NaN
# 17251                    NaN            NaN  NOASSERTION
#
# [17252 rows x 27 columns]

# %%
# Verifica quais dominios dominantes são dominios livres
# Assim tendo uma noção de quantos dominios dominantes não são de empresas
with open("free_email_provider_domains_not_google.txt", "r", encoding="utf-8") as arquivo:
    emails = [email[:-1] for email in arquivo]
sem_gmail = df.loc[df["dominant_domain"].isin(emails)]
sem_gmail
# Out:
#                                                      url  project_id sdtc  \
# 1261           https://github.com/EasyPost/easypost-ruby     1586555    f
# 1842         https://github.com/EasyPost/easypost-python     1885802    f
# 1873                 https://github.com/agkozak/polyglot    63730314    t
# 4897           https://github.com/EasyPost/easypost-java     4265666    t
# 6338   https://github.com/EasyPost/syslog-rfc5424-parser    30951089    f
# 8463         https://github.com/EasyPost/easypost-csharp    10203075    f
# 12117          https://github.com/EasyPost/easypost-node     3406719    f
# 12430  https://github.com/Parrot-Developers/ARSDKBuil...    20216134    t
# 12668  https://github.com/lastship/plugin.video.lastship    70687101    t
# 17078           https://github.com/EasyPost/easypost-php     3233066    f
#
#       mcpc mcve  star_number  commit_count  files    lines  pull_requests  \
# 1261     t    f           85           170   54.0   2655.0             45
# 1842     t    f           57           236   47.0   3163.0             44
# 1873     f    f           56           270   17.0    880.0              2
# 4897     t    f           27           120   73.0   7354.0             22
# 6338     t    f           20            47   24.0    919.0              8
# 8463     t    f           24           258  112.0  46727.0             48
# 12117    t    f           90           269   71.0  25155.0             70
# 12430    f    f          105           262   41.0   7471.0              4
# 12668    f    f           35          1849  100.0  21030.0            243
# 17078    t    f          116           119   64.0   8641.0             25
#
#        ... dominant_domain_authors        cik  fg500 sec10k  sec20f  \
# 1261   ...                       3        NaN    NaN    NaN     NaN
# 1842   ...                       4        NaN    NaN    NaN     NaN
# 1873   ...                       3        NaN    NaN    NaN     NaN
# 4897   ...                       3        NaN    NaN    NaN     NaN
# 6338   ...                       0        NaN    NaN    NaN     NaN
# 8463   ...                      10        NaN    NaN    NaN     NaN
# 12117  ...                       1        NaN    NaN    NaN     NaN
# 12430  ...                      14        NaN    NaN    NaN     NaN
# 12668  ...                       4  1513845.0      f      f       t
# 17078  ...                       2        NaN    NaN    NaN     NaN
#
#                 project_name        owner_login  company_name  owner_company  \
# 1261           easypost-ruby           EasyPost           NaN            NaN
# 1842         easypost-python           EasyPost           NaN            NaN
# 1873                polyglot            agkozak           NaN            NaN
# 4897           easypost-java           EasyPost           NaN            NaN
# 6338   syslog-rfc5424-parser           EasyPost           NaN            NaN
# 8463         easypost-csharp           EasyPost           NaN            NaN
# 12117          easypost-node           EasyPost           NaN            NaN
# 12430        ARSDKBuildUtils  Parrot-Developers           NaN            NaN
# 12668  plugin.video.lastship           lastship   Yandex N.V.            NaN
# 17078           easypost-php           EasyPost           NaN            NaN
#
#             license
# 1261            MIT
# 1842            MIT
# 1873            MIT
# 4897            MIT
# 6338            ISC
# 8463            MIT
# 12117           MIT
# 12430  BSD-3-Clause
# 12668       GPL-3.0
# 17078           MIT
#
# [10 rows x 27 columns]

# %%
# Coluna dominant_domain
dominio_dominante = df["dominant_domain"].dropna()
dominio_dominante
# Out:
# 0          scottlogic.co.uk
# 1             microsoft.com
# 2                object.net
# 3         makina-corpus.com
# 4             travis-ci.com
#                 ...
# 17247            rapid7.com
# 17248           zendesk.com
# 17249    cs.uni-salzburg.at
# 17250         neoway.com.br
# 17251           adacore.com
# Name: dominant_domain, Length: 17252, dtype: object

# %%
lista = df["dominant_domain"].unique()
for x in lista:
    print(x)
# Out:
# scottlogic.co.uk
# microsoft.com
# object.net
# makina-corpus.com
# travis-ci.com
# paddle.com
# ladybirdweb.com
# fb.com
# w11k.de
# hrsoft.net
# 0kn.sakura.ne.jp
# technikum-wien.at
# lbry.io
# wgen.net
# hashicorp.com
# guidesmiths.com
# process-one.net
# twitter.com
# ebuinfo.com
# intel.com
# uber.com
# udacity.com
# elementary.io
# grammatech.com
# codility.com
# tokbox.com
# segment.com
# cloudinary.com
# plex.tv
# replicated.com
# bah.com
# stripe.com
# amazon.com
# pivotal.io
# redhat.com
# icalialabs.com
# janestreet.com
# axosoft.com
# cartodb.com
# storj.io
# icinga.com
# netguru.co
# corp.globo.com
# mozilla.com
# google.com
# gigya-inc.com
# actionsky.com
# automattic.com
# oracle.com
# adobe.com
# roncoo.com
# syss.de
# synercomm.com
# ironcorelabs.com
# polidea.com
# vincit.com
# vmware.com
# kunstmaan.be
# kartoza.com
# b2wdigital.com
# cern.ch
# 500tech.com
# timescale.com
# cozycloud.cc
# benmu-health.com
# forgerock.com
# synadia.com
# arm.com
# jam3.com
# realtimegenomics.com
# usgs.gov
# bbc.co.uk
# unity3d.com
# datacamp.com
# goalgorilla.com
# idealo.de
# avira.com
# jfrog.com
# matterhackers.com
# databricks.com
# recast.ai
# oslandia.com
# mnubo.com
# nearform.com
# confluent.io
# devsu.com
# tu-ilmenau.de
# blackducksoftware.com
# baidu.com
# agiliq.com
# jidesoft.com
# brave.com
# mesosphere.com
# clusterhq.com
# steamclock.com
# chargebee.com
# funkwerk-itk.com
# leapmotion.com
# latera.ru
# infinite.red
# sap.com
# documize.com
# codacy.com
# bangthetable.com
# nokia.com
# mugo.ca
# mailjet.com
# paymaxi.com
# ledger.fr
# neotechnology.com
# emc.com
# goodeggs.com
# resin.io
# solus-project.com
# cliqz.com
# grammarly.com
# tendermint.com
# linux.intel.com
# 2ndquadrant.it
# palantir.com
# integer-net.de
# slack-corp.com
# thoughtworks.com
# rongcloud.cn
# telesign.com
# webgriffe.com
# hasura.io
# npmjs.com
# tig.nl
# wso2.com
# cesanta.com
# gsa.gov
# teambition.com
# mercadolibre.com
# duallab.com
# us.ibm.com
# corp.mail.ru
# launchdarkly.com
# scality.com
# maxmind.com
# conffx.com
# tibco.com
# pal-robotics.com
# datadoghq.com
# voorhoede.nl
# appodeal.com
# tranquil.it
# branch.io
# reactiveops.com
# maidsafe.net
# marel.com
# evojam.com
# pnnl.gov
# criteo.com
# yandex-team.ru
# twokings.nl
# playfab.com
# sinnerschrader.com
# vaadin.com
# medium.com
# amd.com
# starlingbank.com
# 360.cn
# icon.foundation
# linuxacademy.com
# helsinki.fi
# unitedstack.com
# continuum.io
# testdouble.com
# clever.com
# il.ibm.com
# garmin.com
# auth0.com
# imperva.com
# novoda.com
# freshplanet.com
# formidable.com
# parity.io
# juliacomputing.com
# uipath.com
# 3mdeb.com
# rstudio.com
# akveo.com
# couchbase.com
# arduino.cc
# fullcontact.com
# luno.com
# hortonworks.com
# mirantis.com
# taobao.com
# hashrocket.com
# sri.com
# luxoft.com
# usemarkup.com
# dji.com
# consensys.net
# iit.demokritos.gr
# mixi.co.jp
# torchbox.com
# qunar.com
# zte.com.cn
# osi.ca.gov
# transifex.com
# yworks.com
# shapelets.io
# ti.rwth-aachen.de
# pubnub.com
# jetbrains.com
# creditease.cn
# lge.com
# merapar.com
# ncbi.nlm.nih.gov
# aptoide.com
# isbx.com
# trailofbits.com
# circleci.com
# nebulas.io
# go-jek.com
# nimbl3.com
# rocket.chat
# kickstarter.com
# status.im
# zendesk.com
# parkingwang.com
# wix.com
# ufal.mff.cuni.cz
# jiguang.cn
# axoniq.io
# uk.ibm.com
# project-a.com
# mosek.com
# nadeo.com
# ettus.com
# netcetera.com
# loomcom.com
# bitfury.com
# jarsa.com.mx
# reactioncommerce.com
# twobitlabs.com
# massive.co
# zevenet.com
# didichuxing.com
# messagebird.com
# enthought.com
# rackspace.com
# yahoo-inc.com
# acrobotic.com
# swimlane.com
# nylas.com
# digital.cabinet-office.gov.uk
# devexpress.com
# sas.com
# nist.gov
# inria.fr
# rwth-aachen.de
# sifive.com
# sim.tu-darmstadt.de
# xiaonongnv.com
# alterego.biz.ua
# adacore.com
# maxpoint.com
# ericsson.com
# credits.com
# hubspot.com
# bankex.com
# yubico.com
# docusign.com
# claranet.uk
# counsyl.com
# caelum.com.br
# shoutem.com
# ti.com
# swiftkick.it
# enova.com
# nexb.com
# apicloud.com
# teradata.com
# codaxy.com
# coder.com
# rapid7.com
# iron.io
# youzan.com
# rigetti.com
# galeracluster.com
# sourcegraph.com
# appfoundry.be
# beam-mw.com
# bedegaming.com
# spiralscout.com
# qt.io
# wrld3d.com
# illumina.com
# kilograpp.com
# ravenbrook.com
# devbridge.com
# thecontrolgroup.com
# twistlock.com
# liferay.com
# outlandish.com
# jamitlabs.com
# tencent.com
# kingsoft.com
# perimeterx.com
# infor.com
# gettyimages.com
# inovex.de
# alibaba-inc.com
# travelping.com
# qaware.de
# iqmetrix.com
# llnl.gov
# seegno.com
# cumulusnetworks.com
# squaredup.com
# digitalocean.com
# informatik.uni-hamburg.de
# mapbox.com
# opennodecloud.com
# joyent.com
# onyxpoint.com
# yonyou.com
# balsamiq.com
# magento.com
# bitpay.com
# showmax.com
# oreilly.com
# rancher.com
# fishtownanalytics.com
# ustwo.com
# cisco.com
# rabbitmq.com
# codecombat.com
# immunant.com
# 47deg.com
# megvii.com
# rallydev.com
# six-group.com
# remobjects.com
# highfidelity.io
# indeed.com
# it-kartellet.dk
# mdsol.com
# cos.io
# rozdoum.com
# epam.com
# tryolabs.com
# polysync.io
# linuxdeepin.com
# mageplaza.com
# znc.com.br
# funkhaus.us
# tj-fintech.com
# realm.io
# passbolt.com
# bbva.com
# streamr.com
# saul.pw
# antfin.com
# catalyst-au.net
# kitware.com
# calidae.com
# numworks.com
# ona.io
# deligence.com
# dstl.gov.uk
# iex.ec
# spotify.com
# rokid.com
# aftership.com
# framgia.com
# ushahidi.com
# stelligent.com
# shopex.cn
# schibsted.pl
# robotis.com
# coronalabs.com
# haulmont.com
# trek10.com
# solo.io
# tozny.com
# unif.io
# dlg.im
# nccgroup.trust
# sonarsource.com
# 10up.com
# snipcart.com
# opencraft.com
# castironcoding.com
# helium.com
# codeship.com
# thefuntasty.com
# unic.com
# rgi-corp.com
# extremenetworks.com
# roche.com
# affectiva.com
# fauna.com
# atlassian.com
# elastic.co
# ihmc.us
# mundipagg.com
# experius.nl
# stratumn.com
# ornl.gov
# xwp.co
# flatstack.com
# gene.com
# railsware.com
# squareup.com
# jd.com
# onlyoffice.com
# lightcurve.io
# nvidia.com
# net-ng.com
# marklogic.com
# agriya.in
# caffeina.com
# portworx.com
# linkedin.com
# fastly.com
# marketlytics.com
# pearson.com
# sunfounder.com
# plot.ly
# hujiang.com
# ipgp.fr
# navercorp.com
# ipb-halle.de
# xamarin.com
# diennea.com
# onelogin.com
# touk.pl
# okfn.de
# namshi.com
# postgrespro.ru
# nicehash.com
# eoc.ch
# camunda.com
# omise.co
# clever-cloud.com
# codefresh.io
# valor-software.com
# pentaho.com
# citrix.com
# woorank.com
# cerner.com
# austincodingacademy.com
# oursky.com
# mobidev.biz
# lightbend.com
# intuit.com
# redmadrobot.com
# baqend.com
# mwaysolutions.com
# ifactory.com.br
# plivo.com
# esri.com
# mellanox.com
# appscode.com
# kramphub.com
# makandra.de
# cloudogu.com
# ge.com
# bunq.com
# knoldus.com
# arcbees.com
# bubb.com.br
# yixia.com
# wolfssl.com
# stfalcon.com
# jumpcloud.com
# algolia.com
# chalmers.se
# octopus.com
# madetech.com
# asidatascience.com
# lanl.gov
# andela.com
# fokus.fraunhofer.de
# bitnami.com
# ca.com
# sagemath.com
# flipkart.com
# tableau.com
# litres.ru
# delegate.dk
# evercam.io
# nl.ibm.com
# knplabs.com
# streamlabs.com
# userify.com
# nrel.gov
# springload.co.nz
# oxid-esales.com
# vizzuality.com
# intridea.com
# jolicode.com
# machinezone.com
# qxf2.com
# lob.com
# copernica.com
# perfectomobile.com
# ephox.com
# antlersoft.com
# vinta.com.br
# quarkslab.com
# sparkfun.com
# blazemeter.com
# macpaw.com
# cin.ufpe.br
# markekraus.com
# nxp.com
# ekino.com
# dieselpoint.com
# labzero.com
# pykih.com
# sunlightfoundation.com
# jet.com
# netflix.com
# wework.com
# betterment.com
# ooyala.com
# portswigger.net
# alfresco.com
# mebitech.com
# rl-institut.de
# digia.com
# juniper.net
# spartez.com
# codio.com
# aerospike.com
# digitalasset.com
# cloudera.com
# autodesk.com
# elbizri.com
# strikingly.com
# xmartlabs.com
# sidereel.com
# culture.gouv.fr
# truss.works
# geniem.com
# zalando.de
# flagbit.de
# twosigma.com
# fireeye.com
# wallix.com
# realseriousgames.com
# doc.ai
# stardog.com
# imgix.com
# blinkist.com
# jumacc.com
# kx.com
# target.com
# system76.com
# convoy.com
# rocketsoftware.com
# akretion.com
# conductor.com
# dds.mil
# corelight.com
# chef.io
# orangegames.com
# vogella.com
# f5.com
# brightinventions.pl
# maps.me
# webtorque.co.nz
# uc.cl
# domo.com
# quandl.com
# satellogic.com
# paradigm4.com
# scnsoft.com
# informatik.uni-freiburg.de
# seatgeek.com
# scrapinghub.com
# teonite.com
# dataman-inc.com
# theiconic.com.au
# codeyellow.nl
# stratio.com
# bakkenbaeck.no
# apple.com
# octo.com
# yesplan.be
# colloqiconsulting.com
# rasa.com
# gradle.com
# bosch-si.com
# xiaoyouzi.com
# airthium.com
# xilinx.com
# nortal.com
# capitalone.com
# embeddedarm.com
# merck.com
# canonical.com
# pupil-labs.com
# ideus.biz
# freedom.press
# qbatch.com
# m6.fr
# ptsecurity.com
# atmire.com
# devfactory.ch
# gov.bc.ca
# paypal.com
# vungle.com
# jwplayer.com
# klarna.com
# pronovix.com
# linnovate.net
# ahrefs.com
# siteorigin.com
# agency.sc
# daocloud.io
# datto.com
# upai.com
# qw-dev.net
# puppet.com
# dianping.com
# amida.com
# kryptnostic.com
# totvs.com.br
# nike.com
# yalantis.com
# subgraph.com
# metaswitch.com
# dsp.io
# nginx.com
# kloudless.com
# allstate.com
# cypress.io
# pusher.com
# sysdig.com
# wepay.com
# shopify.com
# rub.de
# teracy.com
# neutrinos.co
# iohk.io
# camptocamp.com
# acklenavenue.com
# collabora.com
# async.com.br
# telerik.com
# wormpex.com
# walmartlabs.com
# ird.govt.nz
# threerings.net
# beapi.fr
# sixhours.io
# arangodb.com
# noaa.gov
# robinpowered.com
# jam2in.com
# dwavesys.com
# xpressengine.com
# metamarkets.com
# hashedin.com
# coderedcorp.com
# typefox.io
# mbientlab.com
# cognifide.com
# previousnext.com.au
# umbraco.dk
# belledonne-communications.com
# dev.java.net
# influxdb.com
# irfu.se
# wps.de
# graze.com
# layer.com
# bendingspoons.com
# checkr.com
# lemberg.co.uk
# boldradius.com
# bitovi.com
# spirent.com
# golem.network
# epitech.eu
# qrclab.com
# scmspain.com
# dynatrace.com
# britecore.com
# tapptitude.com
# rangle.io
# fueled.com
# atomist.com
# cultura.gov.br
# inloop.eu
# new4g.cn
# espressif.com
# vechain.com
# syncfusion.com
# mixpanel.com
# clickntap.com
# sdl.com
# coi.gov.pl
# pagar.me
# sinergise.com
# bloomberg.net
# plesk.com
# ebay.com
# ntt.com
# sevenval.com
# semmle.com
# smile.fr
# canaan-creative.com
# easypost.com
# crate.io
# antmicro.com
# jalasoft.com
# sourced.tech
# rambler-co.ru
# docdoku.com
# sitewards.com
# zuora.com
# dockyard.com
# fairfaxmedia.com.au
# pixelandtonic.com
# cea.fr
# ekylibre.com
# estimote.com
# nationalfibre.net
# mendix.com
# axsh.net
# comsysto.com
# opsgenie.com
# ozon.ru
# vonage.com
# tradingeconomics.com
# silverstripe.com
# axiacore.com
# xero.com
# banno.com
# avnet.com
# bigml.com
# diffeo.com
# fysik.dtu.dk
# box.com
# launchbadge.com
# irae.me
# kirasystems.com
# surveymonkey.com
# etondigital.com
# pixar.com
# cognizant.com
# keboola.com
# cloudreach.com
# mogujie.com
# galois.com
# huawei.com
# osedea.com
# upstatement.com
# paraport.com
# supermap.com
# risksense.com
# small-improvements.com
# electrode.alicorn.lv
# mullvad.net
# kooboo.com
# salesagility.com
# gitter.im
# cloudflare.com
# zulily.com
# serpro.gov.br
# mlsdev.com
# pinterest.com
# zensoft.io
# grame.fr
# ocamlpro.com
# zoom.us
# ackee.cz
# anz.com
# nubank.com.br
# architectnow.net
# yunify.com
# nuance.com
# emlid.com
# yuewen.com
# cpqd.com.br
# trobz.com
# samsung.com
# bluerobotics.com
# checkfront.com
# webdevstudios.com
# hazelcast.com
# nuvoton.com
# ebizmarts.com
# iyzico.com
# contrastsecurity.com
# coding.net
# playtika.com
# worksap.co.jp
# razorpay.com
# monax.io
# kkbox.com
# zving.com
# redislabs.com
# jp.ibm.com
# kaleidos.net
# scriptfusion.com
# atsistemas.com
# drotek.com
# tealium.com
# nordicsemi.no
# snips.ai
# emutex.com
# demisto.com
# nasa.gov
# stereolabs.com
# bq.com
# forumone.com
# ecsteam.com
# dxw.com
# keepkey.com
# blackpear.com
# senic.com
# getpostman.com
# nuxeo.com
# voxtecnologia.com.br
# 23andme.com
# nagios.com
# b5m.com
# bam.tech
# mobvoi.com
# mixmax.com
# team-mediaportal.com
# starkandwayne.com
# cloudcannon.com
# quickblox.com
# groupon.com
# lbl.gov
# sigopt.com
# isecpartners.com
# sintef.no
# dlr.de
# euranova.eu
# agilie.com
# skyscrapers.eu
# jpmorgan.com
# dsb.no
# carbonblack.com
# endocode.com
# skymind.io
# upplication.com
# digital.hmrc.gov.uk
# talend.com
# fer.hr
# it-projects.info
# netapp.com
# azavea.com
# address.com
# cloudcms.com
# bluequartz.net
# opendoor.com
# ocado.com
# pulilab.com
# anychart.com
# paymill.de
# temenos.com
# uilicious.com
# analog.com
# praqma.com
# research.att.com
# immomo.com
# gclue.jp
# codebrahma.com
# citusdata.com
# 9gag.com
# vinsol.com
# thorn.ws
# cogini.com
# graphaware.com
# egret.com
# hotoa.com
# grimm-co.com
# ibm.com
# meanbee.com
# codeclimate.com
# sohu-inc.com
# wazuh.com
# vertistudio.com
# ca.ibm.com
# draper.com
# muenchen.de
# odoo.com
# scireum.de
# statsbiblioteket.dk
# sanoma.com
# solita.fi
# acsone.eu
# kite.com
# kensho.com
# guardicore.com
# plumgrid.com
# newrelic.com
# umeng.com
# gdi-service.de
# cyberagent.co.jp
# tegesoft.com
# quobyte.com
# dropbox.com
# tomtom.com
# afterlogic.com
# codingame.com
# uib.no
# puzzle.ch
# urbanairship.com
# c-s.ro
# gengo.com
# izettle.com
# bedatadriven.com
# etsy.com
# zapier.com
# teselagen.com
# mayadata.io
# vivifyideas.com
# sendwithus.com
# capriza.com
# pro-vision.de
# sahusoft.com
# apptension.com
# singree.com
# digikey.com
# tigera.io
# springer.com
# siemens.com
# fffunction.co
# mymusictaste.com
# livechatinc.com
# mcs.anl.gov
# beetech.global
# suse.de
# nodes.dk
# ottogroup.com
# zivtech.com
# liulishuo.com
# bcgsc.ca
# mobilabsolutions.com
# corp.netease.com
# soteradefense.com
# looker.com
# adhocteam.us
# sneakemail.com
# openbionics.com
# viantinc.com
# trend.com.tw
# cryptape.com
# metocean.co.nz
# vipps.no
# magic.io
# axibase.com
# mirumee.com
# uit.no
# runnable.com
# wingify.com
# perficient.com
# deltares.nl
# everis.com
# spideroak.com
# mycompany.com
# snow.dog
# originate.com
# saxsys.de
# iit.it
# moip.com.br
# exosite.com
# netspi.com
# magenic.com
# logz.io
# di.uoa.gr
# nexmo.com
# hoteltonight.com
# metglobal.com
# beeva.com
# steelkiwi.com
# upandrunningsoftware.com
# pluralsight.com
# glosfer.com
# mnemonic.no
# codeplay.com
# oroinc.com
# a24group.com
# nbs-system.com
# zoomeranalytics.com
# thinkshout.com
# synesthesia.it
# expedia.com
# beecloud.cn
# webkul.com
# xcomponent.com
# intelygenz.com
# marpple.com
# infinum.hr
# appliedgeosolutions.com
# desmart.com
# ele.me
# rezo-zero.com
# astrobss.com
# paralect.com
# rhoworld.com
# queensu.ca
# acquia.com
# brtbeacon.com
# engageinteractive.co.uk
# telefonica.com
# nventive.com
# diladele.com
# ministryofvelocity.com
# sparkpost.com
# bitmovin.com
# getkeepsafe.com
# z-wave.me
# xiaomi.com
# vrvis.at
# stxnext.pl
# minexsystems.com
# count.ly
# laboratorium.ee
# qlik.com
# gramener.com
# seafile.com
# instana.com
# platform.sh
# wolfram.com
# codingblocks.com
# apprenda.com
# metosin.fi
# 20c.com
# dreamfactory.com
# fyberlabs.com
# esciencecenter.nl
# baifendian.com
# diconium.com
# nanoporetech.com
# ultimatesoftware.com
# gskinner.com
# chartiq.com
# centreon.com
# alliedtelesis.co.nz
# censys.io
# grafana.com
# trendyol.com
# eathena.ws
# accenture.com
# qti.qualcomm.com
# lokad.com
# bitwise.io
# zumba.com
# easemob.com
# dce.sa
# freeside.biz
# cvent.com
# infoblox.com
# bigroomstudios.com
# eprosima.com
# knowit.se
# twilio.com
# digirati.com
# simpliflow.com
# chaosgroup.com
# digitalbazaar.com
# blend4web.com
# micropyramid.com
# mindera.com
# touchin.ru
# sharetribe.com
# dowjones.com
# liip.ch
# mongodb.com
# 99x.lk
# naxam.net
# iitis.pl
# one.com
# hansonrobotics.com
# mdbootstrap.com
# i6.informatik.rwth-aachen.de
# orionhealth.com
# radixdlt.com
# salesforce.com
# bluecats.com
# techdivision.com
# keep.pt
# digium.com
# meshconsultants.ca
# otto.de
# arachnys.com
# teamwork.com
# heroku.com
# lvlstudio.com
# 5monkeys.se
# gini.net
# admobilize.com
# just-eat.com
# tensult.com
# eurotech.com
# luma-pictures.com
# dp.la
# tune.com
# beyondtrust.com
# rewe-digital.com
# tinkerforge.com
# discordapp.com
# synology.com
# ea.com
# nmma.co
# chikorita157.com
# infragistics.com
# lokku.com
# omb.eop.gov
# mollie.com
# xmos.com
# frepple.com
# terrestris.de
# meltwater.com
# vacuumlabs.com
# weareadaptive.com
# holidayextras.com
# coveo.com
# workiva.com
# erealm.com.my
# windriver.com
# bitcraze.io
# meedan.com
# asiaesolutions.com
# cs.kuleuven.be
# lelesys.com
# sandia.gov
# blend.com
# cloud66.com
# papercut.com
# inductiveautomation.com
# wisedu.com
# tfgco.com
# reisystems.com
# kdab.com
# uma.es
# avito.ru
# rtbhouse.com
# civisanalytics.com
# onchain.com
# nuodb.com
# serpentcs.com
# cognitect.com
# sonatype.com
# locaweb.com.br
# reactai.com
# astronomer.io
# sony.com
# webiny.com
# salsitasoft.com
# cockos.com
# adp.com
# stone.com.br
# element84.com
# transpac.com
# moltin.com
# dna.co.nz
# adroll.com
# collaborne.com
# ilm.com
# sitecore.com
# securekey.com
# code-troopers.com
# dachcom.ch
# eset.com
# onix-systems.com
# motherjones.com
# toggl.com
# mycroft.ai
# sierrawireless.com
# jp.nssol.nssmc.com
# tech-hunters.com
# lewei50.com
# datalogics.com
# zbra.com.br
# thenavisway.com
# minio.io
# creditkarma.com
# ludei.com
# jetreports.com
# cockroachlabs.com
# sismics.com
# bitrise.io
# lesfurets.com
# punkave.com
# paris.fr
# ni.com
# matomy.com
# bluemountaincapital.com
# alkacon.com
# fusioncharts.com
# aligent.com.au
# ultimaker.com
# hatena.ne.jp
# fenecon.de
# scaleapi.com
# fri.uni-lj.si
# cherri.tech
# blue-yonder.com
# gunnjerkens.com
# usabilitydynamics.com
# dataart.com
# streamdata.io
# jbob.io
# wavefront.com
# dnhsoft.com
# cosmosoftware.io
# adyen.com
# kenzan.com
# cognite.com
# infullmobile.com
# broadleafcommerce.com
# doclerholding.com
# improbable.io
# appzio.com
# poynt.co
# corp.ovh.com
# swis.nl
# asiantech.vn
# uds.com.br
# chaitin.com
# wearereasonablepeople.com
# quantconnect.com
# akquinet.de
# powerspace.com
# teltek.es
# preferred.jp
# alexanderthamm.com
# speedment.com
# mailerlite.com
# heltec.cn
# cn.ibm.com
# mega.nz
# webfactory.de
# yiji.com
# contextis.co.uk
# digi.com
# docker.com
# ichano.com
# meituan.com
# brandung.de
# conekta.com
# putao.com
# ellislab.com
# huoyunren.com
# pacificbiosciences.com
# dell.com
# unicon.net
# uptech.team
# lunarg.com
# newegg.com
# hpe.com
# datatorrent.com
# robosense.cn
# qordoba.com
# nerdery.com
# geo-solutions.it
# sensorsdata.cn
# baishancloud.com
# shopware.com
# nativecode.com
# oneapm.com
# aspenmesh.io
# nanome.ai
# z.cash
# csc.fi
# gemtalksystems.com
# linagora.com
# telemidia.puc-rio.br
# ost.com
# modrajagoda.si
# datastax.com
# adguard.com
# greenbone.net
# fortnox.se
# yamoney.ru
# futurice.com
# strongtyped.io
# team-lab.com
# fau.de
# appsflyer.com
# intezer.com
# halcyonmobile.com
# akamai.com
# italianasoftware.com
# dalibo.com
# crunchydata.com
# localytics.com
# coex.cz
# wipro.com
# nic.cz
# ctrip.com
# duosecurity.com
# erlang-solutions.com
# lunarlogic.io
# feisystems.com
# weavora.com
# capgemini.com
# kassiopeia.juls.savba.sk
# pay.nl
# igalia.com
# alfabank.ru
# willowgarage.com
# sequenceiq.com
# mirego.com
# neoway.com.br
# creatis.insa-lyon.fr
# zhuanzhuan.com
# vauxoo.com
# railslove.com
# satoshilabs.com
# pingxx.com
# apizee.com
# wire.com
# lush.co.uk
# gentics.com
# squarespace.com
# bitmain.com
# bastl-instruments.com
# aquaq.co.uk
# tkobr.com
# invisiblethingslab.com
# scania.com
# wlogsolutions.com
# fuzzproductions.com
# uni-ulm.de
# dovecot.fi
# future.co.jp
# rakuten.com
# moodle.com
# buildo.io
# techreceptives.com
# icecave.com.au
# hootsuite.com
# butterflyenergy.ca
# diyatech.com
# frontside.io
# hellofresh.com
# uvasoftware.com
# trikeapps.com
# vipshop.com
# atlantbh.com
# toptal.com
# opendns.com
# corpglory.com
# beansmile.com
# newterm.pl
# openclovis.com
# adlnet.gov
# appcelerator.com
# contiamo.com
# iis.ee.ethz.ch
# terradue.com
# presslabs.com
# soartech.com
# appnexus.com
# qubole.com
# covermymeds.com
# decathlon.com
# fenbi.com
# s24.com
# luoyun.co
# anaconda.com
# esi.dz
# fizyr.com
# restlet.com
# plangrid.com
# lucidworks.com
# octoblu.com
# goodrain.com
# rethinkdb.com
# boost.co.nz
# am-impact.nl
# vector35.com
# exoplatform.com
# infotel.com
# nhnent.com
# gridsolar.jp
# tivix.com
# adjust.com
# redsolution.ru
# restream.rt.ru
# araxia.net
# ficonsulting.com
# opengamma.com
# ca2.cc
# geomatys.com
# vimeo.com
# cls.fr
# luminoso.com
# linecorp.com
# supercharge.io
# zhihu.com
# evidence.eu.com
# ag-projects.com
# businessdecision.com
# galvanize.com
# greenbytes.de
# strangerstudios.com
# consol.de
# mediamonks.com
# aspose.com
# soixantecircuits.fr
# dcx.bz
# citizencode.io
# janeirodigital.com
# teclib.com
# se7ensky.com
# leap.se
# tiolive.com
# justgiving.com
# dbc.dk
# saucelabs.com
# turbonomic.com
# obeo.fr
# greenhost.nl
# iotic-labs.com
# h-o.nl
# booking.com
# 10xgenomics.com
# lahautesociete.com
# cargomedia.ch
# skcript.com
# usp.br
# optum.com
# jumpmind.com
# playcanvas.com
# techsmith.com
# arello-mobile.com
# superblocks.com
# cgi.com
# jibo.com
# semantics3.com
# smartling.com
# iwaimai.baidu.com
# godaddy.com
# maxserv.com
# nearit.com
# savoirfairelinux.com
# datasoft.com
# lumapps.com
# sbb.ch
# activecampaign.com
# mintel.com
# pgs-soft.com
# noredink.com
# xkeshi.com
# loopeer.com
# balabit.com
# blizzard.com
# lucidchart.com
# nxrobo.com
# pokitdok.com
# mindtronicai.com
# radiusnetworks.com
# kabbage.com
# ara.com
# fitbit.com
# kivra.com
# fortanix.com
# lombiq.com
# ripe.net
# squidsolutions.com
# e-hps.com
# emqtt.io
# parolu.io
# evodeck.com
# infobip.com
# stackoverflow.com
# onera.fr
# wikia-inc.com
# amplify.com
# koding.com
# inwinstack.com
# suixingpay.com
# synopsys.com
# touchstone.east.ora.com
# teamleader.eu
# itdhq.com
# griddynamics.com
# codenvy.com
# ipd.info.uni-karlsruhe.de
# bizo.com
# dianrong.com
# whizzosoftware.com
# bluedigm.com
# jballou.com
# appscale.com
# scichart.com
# ocelotconsulting.com
# endlessm.com
# giai.tech
# basecamp.com
# alumnos.upm.es
# uncharted.software
# headwire.com
# mediamath.com
# pspdfkit.com
# ridi.com
# opencredo.com
# shapeways.com
# brickblock.io
# lindenbaum.eu
# blackberry.com
# dev2.co.za
# airbnb.com
# roblox.com
# objectivity.co.uk
# openx.com
# revelry.co
# netgen.hr
# radialpoint.com
# parc.com
# comcast.com
# braintec-group.com
# nitrokey.com
# applozic.com
# medley.jp
# zetetic.net
# linkernetworks.com
# appgyver.com
# mparticle.com
# goshippo.com
# ravendb.net
# heapanalytics.com
# knownsec.com
# isaac.nl
# pycom.io
# clarifai.com
# splicemachine.com
# tomatocart.com
# ez.no
# utwente.nl
# stratisplatform.com
# flingos.co.uk
# reddit.com
# hostnet.nl
# binpar.com
# smooch.io
# hackclub.com
# cloudrail.com
# wavesplatform.com
# shapesecurity.com
# cloudbees.com
# ukaea.uk
# wallaroolabs.com
# okta.com
# cs.rwth-aachen.de
# averoinc.com
# lab2023.com
# nordstrom.com
# kayac.com
# elao.com
# helpshift.com
# lumoslabs.com
# octaveoctave.com
# storageos.com
# orobix.com
# postsharp.net
# getsocial.im
# disa.im
# esss.com.br
# in2code.de
# cloudius-systems.com
# seeburger.de
# fun-box.ru
# tusdk.com
# emag.ro
# isti.cnr.it
# instacart.com
# alteryx.com
# suse.com
# metrological.com
# microblink.com
# mantech.co.kr
# barefootnetworks.com
# arconsis.com
# jpl.nasa.gov
# knime.com
# irail.be
# itaapy.com
# castlabs.com
# wilddog.com
# dkfz-heidelberg.de
# apsl.net
# archilogic.com
# softmotions.com
# rapidminer.com
# leanplum.com
# touchlab.co
# whiteboard-it.com
# deltadna.com
# learnosity.com
# successivesoftwares.com
# revinate.com
# cdskysoft.com
# cycling74.com
# buoyant.io
# asobostudio.com
# cloud-ark.com
# basistech.com
# everything.me
# authlete.com
# bitcoinbank.co.jp
# praqma.net
# outsystems.com
# basware.com
# mastodonc.com
# vizir.com.br
# streamsets.com
# smartface.io
# nets.com.pl
# akeneo.com
# flyingcircus.io
# lmco.com
# virtualopensystems.com
# webtide.com
# yelp.com
# signavio.com
# respec.com
# esrf.fr
# flant.com
# netways.de
# postlight.com
# impetus.co.in
# zeroengine.io
# grandcentrix.net
# ifanr.com
# tagbangers.co.jp
# srcclr.com
# canaltp.fr
# fossee.in
# tangocard.com
# enki.com
# barco.com
# cib.de
# news.com.au
# tripaneer.com
# makingsense.com
# multidots.com
# porscheinformatik.at
# 1and1.ro
# bitmark.com
# levelupdevelopment.com
# pythian.com
# parallax.com
# camba.coop
# wiredcraft.com
# asana.com
# eos.ubc.ca
# made.com
# barracuda.com
# sumologic.com
# modelon.com
# tu-dresden.de
# dangdang.com
# univ-lemans.fr
# weinzierl.de
# rti.com
# seravo.fi
# sipwise.com
# fit2cloud.com
# resultadosdigitais.com.br
# edf.fr
# cloveretl.com
# peopleperhour.com
# medlmobile.com
# sitepen.com
# gear.it
# workday.com
# bopen.eu
# tcpcloud.eu
# epicgames.com
# weka.io
# xq-web.de
# socreate.it
# embecosm.com
# totalgood.com
# fuerteint.com
# axelor.com
# lutraconsulting.co.uk
# altran.com
# possible.com
# theappbusiness.com
# yext.com
# desy.de
# netz98.de
# softwareradiosystems.com
# codecentric.de
# arista.com
# jahia.com
# janrain.com
# telaxus.com
# kumparan.com
# am.is
# cnrs.fr
# wiznet.co.kr
# yy.com
# polyconseil.fr
# 42.nl
# pasteur.fr
# leapmind.io
# plt.rwth-aachen.de
# nfl.com
# elico-corp.com
# bfh.ch
# turbulenz.com
# bitzesty.com
# skroutz.gr
# surfstudio.ru
# hdsxtech.com
# irontec.com
# nohana.co.jp
# epsagon.com
# mariadb.com
# usc.es
# unit9.com
# bigstep.com
# asiainfo.com
# rickmacgillis.com
# dwolla.com
# grakn.ai
# studio24.net
# 1c.ru
# zeiss.com
# capensis.fr
# chukong-inc.com
# correo.ugr.es
# teko.vn
# viadeoteam.com
# goinvo.com
# eng.it
# xietingdemini.lan
# transferwise.com
# voormedia.com
# kaufhof.de
# flexport.com
# kmkonline.co.id
# dtstack.com
# is-land.com.tw
# aptible.com
# cookpad.com
# tngtech.com
# progress.com
# pagerduty.com
# 1und1.de
# opendatagroup.com
# kaltura.com
# gentex.com
# gigaspaces.com
# rankone.io
# litespeedtech.com
# thinkful.com
# matricks.se
# reverb.com
# wanelo.com
# ft.com
# tue.nl
# thecodingmachine.com
# activeeon.com
# ictu.nl
# binary.com
# phcnetworks.net
# stamplay.com
# kenshoo.com
# bericotechnologies.com
# metacell.us
# yarooze.com
# firewalla.com
# signiant.com
# sysgears.com
# pivotallabs.com
# teamcmp.com
# grundid.de
# westarete.com
# ama-inc.com
# surfsara.nl
# wolk.com
# wirecard.com
# opendatasoft.com
# wearejh.com
# futuremind.com
# 24bitgames.com
# lorenwest.com
# boundlessgeo.com
# bambucode.com
# encamina.com
# enjin.com
# fraudmarc.com
# automatic.com
# acrcloud.com
# onyx-international.com
# wolox.com.ar
# amadeus.com
# ine.com
# openlabs.co.in
# selleo.com
# getambassador.com
# shephertz.co.in
# spaceuptech.com
# planet.com
# cscs.ch
# rt-thread.com
# envoy.com
# gaia3d.com
# johndeere.com
# zhaw.ch
# varnish-software.com
# lantanagroup.com
# catalyst.net.nz
# bleez.com.br
# quintel.com
# pcextreme.nl
# virtoway.com
# deutschebahn.com
# bigbitecreative.com
# doximity.com
# nlnetlabs.nl
# 5xruby.tw
# gridgain.com
# nexogen.hu
# dabapps.com
# caktusgroup.com
# envionsoftware.com
# csiro.au
# rock-chips.com
# intven.com
# dips.no
# ece.ubc.ca
# oath.com
# spatie.be
# xsolla.com
# instructure.com
# develer.com
# f00l.de
# bcvsolutions.eu
# bskyb.com
# zymobi.com
# imaginex.cl
# jivygroup.com
# tinkoff.ru
# cryptic.li
# plainconcepts.com
# openio.io
# tri.global
# kata.ai
# exablaze.com
# kartverket.no
# sipgate.de
# onestein.nl
# adorsys.de
# welaika.com
# smartsheet.com
# bgeo.es
# sinch.com
# hightech.today
# eventbrite.com
# megam.io
# tailored-apps.com
# put.as
# socialwifi.com
# jivesoftware.com
# snappydata.io
# ecreall.com
# cybozu.co.jp
# bitkeeper.com
# paloaltonetworks.com
# nextdoor.com
# oneniceapp.com
# corp.badoo.com
# dfki.de
# polyverse.io
# gooddata.com
# ashn.com
# psiphon.ca
# dashbot.io
# gsi.de
# clickstorm.de
# switch-company.com
# savoirtech.com
# azoft.com
# signalfx.com
# unity-robotics.de
# prolificinteractive.com
# piwik.pro
# devscope.net
# cosmosfarm.com
# loc.gov
# cultofcoders.com
# shippable.com
# thought.co.uk
# linbit.com
# pricingassistant.com
# micromata.de
# chaordicsystems.com
# camera360.com
# dnanexus.com
# vivid-planet.com
# twdb.texas.gov
# treasure-data.com
# srdc.com.tr
# luaforge.net
# checkpoint.com
# kalamuna.com
# cloud-elements.com
# algoryx.se
# lavaina.com
# web-feet.co.uk
# excella.com
# kaliop.com
# lgsinnovations.com
# device42.com
# biicode.com
# sektioneins.de
# bigswitch.com
# xiag.ch
# caci.com
# smartthings.com
# nordsoftware.com
# zhongan.io
# rtcamp.com
# sevun.com
# nimbisservices.com
# ugrid.net
# pozyx.io
# bekk.no
# flashphoner.com
# omega-r.com
# yipl.com.np
# marmelab.com
# swiftstack.com
# mail.worksap.com
# ridgerun.com
# episerver.com
# comverge.com
# sungardas.com
# opentrons.com
# gofreerange.com
# bee42.com
# prophetstor.com
# dooapp.com
# block.one
# onesignal.com
# frequentis.com
# zeroc.com
# configit.com
# zulipchat.com
# quanterall.com
# hashmapinc.com
# metaways.de
# edmunds.com
# radgeek.com
# sogilis.com
# smartnsoft.com
# helabs.com
# kleder.co
# redpitaya.com
# ecrins-parcnational.fr
# bigtreetc.com
# virtuslab.com
# burkesoftware.com
# eligible.com
# ellucian.com
# pds.nl
# semantic-ui.com
# bia-boeing.com
# novatec-gmbh.de
# riotgames.com
# mcneel.com
# sidefx.com
# omines.com
# till-wiese.de
# cloudalize.com
# lord.com
# steema.com
# live2d.com
# ragnarson.com
# hp.com
# tokopedia.com
# itglobal.ru
# xlink.cn
# syncad.com
# kkovacs.eu
# eleks.com
# yunojuno.com
# engineerbetter.com
# extremevision.com.cn
# codedx.com
# upwork.com
# thesoftwarehouse.pl
# justcoded.com
# calytrix.com
# promactinfo.com
# applidium.com
# idega.com
# blueriver.com
# umisoft.ru
# pnfsoftware.com
# stackify.com
# quickenloans.com
# localprojects.com
# adhoc.com.ar
# rightscale.com
# mapgis.com
# roku.com
# clearmatics.com
# gaig.com
# prominentedge.com
# addthis.com
# sendinblue.com
# aporeto.com
# udk-berlin.de
# infosupport.com
# outscale.com
# fu-berlin.de
# web-education.net
# campuscode.com.br
# goquiq.com
# miracl.com
# abbyy.com
# campanja.com
# craftersoftware.com
# quantopian.com
# slightech.com
# pixelfusion.co.nz
# premium-minds.com
# mittwald.de
# exasol.com
# hd123.com
# zstack.io
# compent.net
# kineo.com
# virtualcitysystems.de
# geneegroup.com
# synacor.com
# lexisnexis.com
# bullhorn.com
# procore.com
# nitesh.name
# radicalbit.io
# genomoncology.com
# jscrambler.com
# t-mobile.com
# tanium.com
# emergya.com
# phusion.nl
# lovoo.com
# autogeneral.com.au
# paymentwall.com
# xfive.co
# cinnober.com
# biosistemika.com
# mixedmedialabs.com
# douban.com
# giorgi.net
# thinkst.com
# cask.co
# smartive.ch
# ggusoft.com
# cnag.crg.eu
# initforthe.com
# slock.it
# untangle.com
# scilifelab.se
# eclipsesource.com
# siftscience.com
# vngrs.com
# nuagenetworks.net
# ihomer.nl
# blablacar.com
# fivem.net
# moove-it.com
# chanzuckerberg.com
# ethz.ch
# scand.com
# deeson.co.uk
# jobandesther.com
# makewave.com
# redradix.com
# natural-solutions.eu
# lazada.com
# seldon.io
# franz.com
# monterail.com
# teluu.com
# bellycard.com
# clozure.com
# willowtreeapps.com
# zededa.com
# bbn.com
# almacom.co.th
# solana.com
# informatik.uni-leipzig.de
# incarcloud.com
# zeroturnaround.com
# shopkick.com
# holisticon.de
# cocoanetics.com
# avinetworks.com
# copperspice.com
# smarkets.com
# jaystack.com
# entelect.co.za
# connexta.com
# neogov.net
# zuehlke.com
# taximaxim.ru
# novartis.com
# aap.com.au
# dyn.com
# careerbuilder.com
# vtex.com.br
# splunk.com
# higherfrequencytrading.com
# freshworks.com
# codecoup.pl
# openknowledge.de
# bitergia.com
# cibotechnologies.com
# enimai.com
# svengine.com
# travelaudience.com
# ru.is
# ecmwf.int
# zef.fi
# bonprix.net
# tmit.bme.hu
# mx.com
# cubewise.com
# trendmicro.com
# noveogroup.com
# eficent.com
# tobit.software
# guidewire.com
# nabto.com
# icicletech.com
# bubi.cn
# prograils.com
# commercetools.de
# mobify.com
# ambitenergy.com
# canada.ca
# fkie.fraunhofer.de
# 139.com
# keyholesoftware.com
# taxjar.com
# wiley.com
# wildcodeschool.fr
# codilime.com
# mxchip.com
# e-consystems.com
# king.com
# sky.uk
# scandiweb.com
# pymetrics.com
# threatstack.com
# virgilsecurity.com
# metoffice.gov.uk
# tecnospeed.com.br
# kayak.com
# brightcove.com
# 51degrees.com
# tag-games.com
# dragonfly.co.nz
# gizra.com
# vast.com
# hand-china.com
# gameduell.de
# shuyun.com
# wheniwork.com
# yunphant.com
# forio.com
# iro.umontreal.ca
# taotesting.com
# tudelft.nl
# hablapps.com
# ainfosec.com
# wikitude.com
# thinktecture.com
# kezaihui.com
# stylefruits.de
# curefit.com
# ifunfactory.com
# alipay.com
# teknik.io
# tenable.com
# starschema.net
# moderndevice.com
# esendex.com
# val.co.jp
# gmx.co.uk
# oanda.com
# inl.gov
# tippingcanoe.com
# label305.com
# geekytheory.com
# snowplowanalytics.com
# oxygenxml.com
# coxautoinc.com
# oblong.com
# despark.com
# nowina.lu
# optionfactory.net
# crystalnix.com
# sensenet.com
# beckman.com
# roli.com
# sit.fraunhofer.de
# softinstigate.com
# softwareag.com
# stackpointcloud.com
# scilab-enterprises.com
# affirm.com
# spryker.com
# clover.com
# objectstyle.com
# analysys.com.cn
# descarteslabs.com
# 25th-floor.com
# combodo.com
# movisens.com
# sendbird.com
# csl.sri.com
# shogo.ru
# siwei.tech
# ts.fujitsu.com
# variflight.com
# genode-labs.com
# normation.com
# stitchdata.com
# extensionengine.com
# sketchfab.com
# m-industries.com
# meizu.com
# mmc-agentur.at
# shiftleft.io
# tikalk.com
# datakernel.io
# evoila.de
# evolveum.com
# xbrl.us
# h2o.ai
# zolertia.com
# hdactech.com
# socialpoint.es
# pilz.de
# polymtl.ca
# socialbakers.com
# nilenso.com
# severalnines.com
# coinbase.com
# rademade.com
# lp-digital.fr
# bluespec.com
# fabtotum.com
# bri.io
# paybase.io
# telestax.com
# gvit.com
# silktide.com
# itglue.com
# tiledb.io
# dnd.fr
# pdftron.com
# asus.com
# gotokeep.com
# idea-synergy.com
# data61.csiro.au
# mcmaster.com
# touchlane.com
# viva64.com
# kagilum.com
# phantombuster.com
# woai.ru
# magefan.com
# jetruby.com
# canviz.com
# mapd.com
# altschool.com
# avaloq.com
# neto.com.au
# appunite.com
# unipro.ru
# quintagroup.com
# eve.tools
# lightspeedhq.com
# op5.com
# de.adit-jv.com
# hotelbeds.com
# openclinica.com
# intevation.de
# jollamobile.com
# wacai.com
# skyspecs.com
# deepomatic.com
# cj.com
# openanalytics.eu
# crs4.it
# echonest.com
# wisertogether.com
# fivestars.com
# mulesoft.com
# immense.net
# namics.com
# intermedix.com
# islog.com
# mappy.com
# obsidian.systems
# 3pillarglobal.com
# qubitdigital.com
# usbr.gov
# osisoft.com
# casperoakley.com
# exobytestudio.com
# metageek.net
# th-nuernberg.de
# eonerc.rwth-aachen.de
# dc-square.de
# disneyresearch.com
# coveros.com
# oxalide.com
# nuls.io
# ball.com
# yetanalytics.com
# africastalking.com
# derivco.co.uk
# wikimedia.de
# bandwidth.com
# bsc.es
# kyligence.io
# migeran.com
# intermodalics.eu
# citystateentertainment.com
# console.com.au
# wherelabs.com
# venmo.com
# 2gis.ru
# weebly.com
# novicell.dk
# fixstars.com
# kuali.co
# valtech.de
# tst.jus.br
# umcutrecht.nl
# objectbox.io
# madebyhiro.com
# unosquare.com
# crowdfavorite.com
# powel.com
# xing.com
# keepersecurity.com
# multisafepay.com
# spantree.net
# asos.com
# praetorian.com
# fiverr.com
# polyswarm.io
# jabong.com
# synergex.com
# scalac.io
# brander.ua
# link.it
# inf.u-szeged.hu
# pojo.me
# seibert-media.net
# eventespresso.com
# nethesis.it
# sbgenomics.com
# klab.com
# groupdocs.com
# qiniu.com
# rte-france.com
# bluecatnetworks.com
# hedvig.com
# dexterindustries.com
# entando.com
# verisign.com
# allegro.pl
# bluesoft.com.br
# seemecnc.com
# cartologic.com
# magnet.com
# mosync.com
# evolutiongaming.com
# valvesoftware.com
# bnl.gov
# logicify.com
# iais.fraunhofer.de
# pixelgrade.com
# cksource.com
# liveperson.com
# dimagi.com
# ctidigital.com
# quamotion.mobi
# swirrl.com
# ripple.com
# tier4.jp
# vinades.vn
# db.com
# t-sciences.com
# qaprosoft.com
# dotmailer.com
# rootstrap.com
# optimad.it
# tcd.ie
# dxy.cn
# itg.com
# mist.io
# netsmarttech.com
# roundglobe.tech
# thriveweb.com.au
# xamla.com
# jumpbyte.com
# linuxserver.io
# metsci.com
# lbm.co
# bw-sw.com
# sterc.nl
# clover-studio.com
# jfrj.jus.br
# hoperun.com
# shadowrobot.com
# idevicesinc.com
# bytedance.com
# playlyfe.com
# i2cat.net
# inetsoftware.de
# nearsoft.com
# livetex.ru
# unrulygroup.com
# sixsq.com
# edited.com
# mpi-cbg.de
# goodow.com
# pads.rwth-aachen.de
# madewithlove.be
# vertex.link
# streampunk.media
# clearcode.cc
# gurum.cc
# qiyi.com
# thingsboard.io
# thorgate.eu
# viison.com
# bol.com
# originprotocol.com
# fanruan.com
# viadee.de
# rareloop.com
# hudson-trading.com
# .emsys.net
# opsmanager.com
# recurly.com
# wallarm.com
# daynix.com
# deezer.com
# illinoisrocstar.com
# breadwallet.com
# themidnightcoders.com
# capsule8.com
# unistra.fr
# comindware.com
# 2600hz.com
# f-secure.com
# mylaurier.ca
# dotcms.com
# convert.no
# polylytics.com
# zib.de
# treeptik.fr
# cihologramas.com
# eleith.com
# norcom.de
# tumblr.com
# worthwhile.com
# payu.ro
# its.jnj.com
# boeing.com
# getweave.com
# al.com.au
# mcafee.com
# homeaway.com
# soundcloud.com
# airensoft.com
# kuleuven.be
# videopls.com
# altkom.pl
# linn.co.uk
# shuup.com
# metova.com
# zhiqim.com
# infosimples.com.br
# cba.com.au
# octo.im
# disneyanimation.com
# coorpacademy.com
# potix.com
# cimpress.com
# fancs.com
# cloudhealthtech.com
# greentube.com
# cloudant.com
# sitescout.com
# easytaxi.com.br
# abc-arbitrage.com
# cinchapi.com
# airmap.com
# iteratec.de
# salsify.com
# scylladb.com
# schibsted.com
# 2dfire.com
# purestorage.com
# upm.es
# elastacloud.com
# code42.com
# darksky.net
# rea-group.com
# shopsys.com
# globallogic.com
# smartprix.com
# ezbuy.com
# logentries.com
# xtraball.com
# hogarthww.com
# flax.co.uk
# bonitasoft.com
# digitalsurgeons.com
# multicorewareinc.com
# altair.com
# enalean.com
# progressive.com
# ibitcy.com
# xlab.si
# kpn.com
# aiyaapp.com
# netresearch.de
# maibornwolff.de
# metamagic.in
# geetest.com
# y-less.com
# genoscope.cns.fr
# soldevelo.com
# tomitribe.com
# orbotix.com
# wildbit.com
# viromedia.com
# vlocity.com
# dnnsoftware.com
# commercetools.com
# joinquant.com
# tno.nl
# absolunet.com
# tendenci.com
# devartis.com
# tuenti.com
# mykolab.com
# lenovo.com
# burohappold.com
# netseven.it
# staff.weibo.com
# plotprojects.com
# pololu.com
# 9elements.com
# molpay.com
# magrathealabs.com
# jdm.nl
# mhand.net
# tecsisa.com
# kodi.tv
# climber.se
# enews.nrl.navy.mil
# paymentsense.com
# apstra.com
# creditas.com.br
# jaseg.net
# fast-report.com
# pragmatists.pl
# firma.seznam.cz
# wargaming.net
# nextcentury.com
# ekumenlabs.com
# esgyn.com
# pressbooks.com
# maxeler.com
# open.ch
# bluedata.com
# eisgroup.com
# teamaol.com
# biig.fr
# decsai.ugr.es
# temasys.com.sg
# dualcube.com
# xtreme-eda.com
# avast.com
# bingosoft.net
# labri.fr
# gopivotal.com
# bmw.de
# multunus.com
# vodjk.com
# ixds.com
# everyonecounts.com
# ugcs.com
# up2go.com
# adjacentlink.com
# gurtam.com
# geographica.gs
# arcadia.spb.ru
# kashoo.com
# in.ibm.com
# dneg.com
# datawire.io
# srlabs.de
# profitbricks.com
# red6-es.de
# catalysts.cc
# adafruit.com
# tron.network
# stud.fit.vutbr.cz
# makersacademy.com
# fim.uni-passau.de
# meetup.com
# scotiabank.com
# surespot.me
# unibas.ch
# retest.de
# despegar.com
# atechmedia.com
# zego.im
# utah.gov
# orange.com
# le-tex.de
# commandprompt.com
# webfilings.com
# intermesh.nl
# uni-wuerzburg.de
# sesilio.com
# absint.com
# compucorp.co.uk
# vanillaforums.com
# slb.com
# lcad.inf.ufes.br
# skbkontur.ru
# lucky-kat.com
# sociomantic.com
# joshtechnologygroup.com
# switch-science.com
# internap.com
# bitnine.net
# prismtech.com
# cnb.csic.es
# lemoncode.net
# tagview.com.br
# zenoss.com
# embeddedartists.com
# donders.ru.nl
# n-dream.com
# fundingcircle.com
# prestashop.com
# optimal-dynamics.com
# exact.com
# bisdn.de
# gamonoid.com
# cradlepoint.com
# amplitude.com
# microfocus.com
# keedio.com
# picwell.com
# bitgo.com
# yoast.com
# derbysoft.com
# bebo.com
# manticoresearch.com
# gemalto.com
# mail.i2p
# inthepocket.mobi
# smartdec.ru
# mobstac.com
# xtuple.com
# enioka.com
# pl.ibm.com
# gripstudios.com
# launchkey.com
# xindong.com
# medallia.com
# cloudbasesolutions.com
# gofore.com
# fds.vn
# trivago.com
# froiden.com
# logistimo.com
# tanker.io
# elphel.com
# lykke.com
# laas.fr
# simplybusiness.co.uk
# fz-juelich.de
# farmbio.uu.se
# anl.gov
# axiros.com
# smartcar.com
# ideum.com
# stackbuilders.com
# asideas.de
# gameboxcloud.com
# webtech.co.jp
# snyk.io
# apeunit.com
# pandora.com
# pingcap.com
# streamhpc.com
# zagaran.com
# sonalake.com
# amdocs.com
# osbzr.com
# d2l.com
# nordigy.ru
# caicloud.io
# opensides.be
# msp.gouv.qc.ca
# mirasvit.com
# uni-bremen.de
# saltstack.com
# census-labs.com
# reaktor.com
# disid.com
# sones.com
# servicenow.com
# confluxtechnologies.com
# chartbeat.com
# infobytesec.com
# quisquis.de
# grupawp.pl
# republicprotocol.com
# physik.uni-bonn.de
# maplecroft.com
# francelabs.com
# ux-xu.com
# woowahan.com
# ippon.fr
# intellitect.com
# shinetechchina.com
# gopro.com
# codurance.com
# discoverygarden.ca
# graft.network
# alces-software.com
# intentionet.com
# ideo.pl
# leankit.com
# baylibre.com
# teleca.com
# addlevel.se
# trust1team.com
# jahnelgroup.com
# voltdb.com
# ient.rwth-aachen.de
# eduworks.com
# idiap.ch
# gravity.com
# ssi.gouv.fr
# continuum.cl
# clearpathrobotics.com
# roboception.de
# liveramp.com
# genesilico.pl
# autotelik.co.uk
# fruitfulcode.com
# nbb.be
# lovell.info
# mendeley.com
# indexdata.com
# movio.co
# apptentive.com
# ra.rockwell.com
# traveloka.com
# nuco.io
# extrahop.com
# tesseris.com
# objectbright.com
# ctrlc.hu
# climate.com
# blackbaud.com
# tigerknows.com
# threatconnect.com
# springsignage.com
# vilt-group.com
# points.com
# clock.co.uk
# zenner-iot.com
# uclouvain.be
# itemis.de
# rapidlasso.com
# beisen.com
# sisa-tech.com
# idealista.com
# ramotion.com
# klevstul.com
# toyotaconnected.com
# se-rwth.de
# blockchain.com
# kaazing.com
# mpa-garching.mpg.de
# veritone.com
# haodai.net
# brioconcept.com
# healthcatalyst.com
# perfectsensedigital.com
# axa.fr
# bitaccess.co
# companieshouse.gov.uk
# mondora.com
# office.ngs.ru
# icarus-consult.de
# solidfire.com
# uni-muenster.de
# ccri.com
# seekingalpha.com
# unime.it
# access-company.com
# victronenergy.com
# lmax.com
# rsk.co
# kmc.gr.jp
# telenav.com
# pubmatic.com
# ucalgary.ca
# blackboard.com
# we45.com
# neueda.com
# myparcel.nl
# sonicgarden.jp
# ionic.io
# termmed.com
# natpryce.com
# rethinkrobotics.com
# talpor.com
# coralteq.com
# us.fujitsu.com
# iwayvietnam.com
# abrakam.com
# northern.tech
# sirrix.com
# kozea.fr
# autorally.github.io
# atos.net
# verizondigitalmedia.com
# drifty.com
# yinheark.com
# sixfeetup.com
# tenxcloud.com
# hulu.com
# koheron.com
# ilscipio.com
# ugent.be
# xebia.com
# camelotbio.com
# otrs.com
# uji.es
# mobilejazz.com
# avalara.com
# intervolga.ru
# microstrategy.com
# nopcommerce.com
# ispringsolutions.com
# cyberbotics.com
# getui.com
# qnap.com
# exntu.com
# socib.es
# telldus.se
# numato.com
# twosixlabs.com
# sefin.ro.gov.br
# enigma.co
# dplrn.com
# devexperts.com
# modolabs.com
# whmcs.com
# ibuildings.nl
# phantom.industries
# ziaconsulting.com
# getmangos.eu
# staff.sina.com.cn
# qcadoo.com
# dwarvesf.com
# moventes.com
# zillowgroup.com
# datascience.com
# woltlab.com
# metasfresh.com
# irt.de
# student.his.se
# openlinksw.com
# dunbarsecured.com
# boldcommerce.com
# insa-rennes.fr
# qiyuesuo.com
# guardtime.com
# concrete.com.br
# picotech.com
# imgtec.com
# fullstory.com
# venturedive.com
# sztaki.mta.hu
# agilelab.it
# statkraft.com
# licor.com
# mewssystems.com
# wizeline.com
# thinkboxsoftware.com
# dwango.co.jp
# rubicon.eu
# shinesolutions.com
# telenordigital.com
# trippingthebits.com
# safe.com
# fixate.it
# iotex.io
# leapfrogonline.com
# cpanel.net
# kiwigrid.com
# reaktor.fi
# elpassion.pl
# prometsource.com
# vagalume.com.br
# loggly.com
# getperka.com
# inextrix.com
# aimotive.com
# nersc.no
# smgov.net
# lyft.com
# ideablade.com
# thomsonreuters.com
# usechain.net
# uni-tuebingen.de
# cigna.com
# dolittle.com
# uptake.com
# apposit.com
# bestit-online.de
# sakura.ad.jp
# dvelp.co.uk
# scimedsolutions.com
# kibatic.com
# omniasolutions.eu
# express.com
# optimizely.com
# mentor.com
# synthace.com
# mirai-solutions.com
# powerfolder.com
# foursquare.com
# ubuntu.com
# allwinnertech.com
# epu.ntua.gr
# mokeedev.com
# nayuta.co
# esrlabs.com
# bluemoon.com.cn
# redventures.com
# axway.com
# letsrobot.tv
# esrifrance.fr
# synerzip.com
# creare.com
# inuits.eu
# nullsecurity.net
# commvault.com
# idcos.com
# inverse.ca
# sumup.com
# fargeo.com
# ubc.ca
# lendingclub.com
# openailab.com
# loldesign.com.br
# orbitone.com
# smartbear.com
# trustedsec.com
# android.com
# ithouse.lv
# stamus-networks.com
# finn.no
# hhi.fraunhofer.de
# nexenta.com
# trustly.com
# cloudlinux.com
# runalyze.com
# volexity.com
# tresys.com
# arch.ethz.ch
# bo3b.net
# epa.gov
# husarion.com
# geolytix.co.uk
# bigcommerce.com
# enda.eu
# imagescape.com
# ux3d.io
# deinternetjongens.nl
# sprinklr.com
# red-gate.com
# usebutton.com
# diffblue.com
# jabra.com
# nashtechglobal.com
# enonic.com
# raizlabs.com
# sensenet.nu
# wunderdog.fi
# uptickhq.com
# travix.com
# astamuse.co.jp
# ecometrica.com
# accoliteindia.com
# neuland-bfi.de
# lastcallmedia.com
# ruffer.co.uk
# hdivsecurity.com
# makerdao.com
# vicompany.nl
# agilebits.com
# datartisan.com
# jawbone.com
# enough.de
# digitalriver.com
# sk-consulting.com.ua
# fel.cvut.cz
# hotels.com
# zemanta.com
# 11paths.com
# spinit.se
# mindcandy.com
# ma.tum.de
# gigigo.com
# sportngin.com
# cwi.com.br
# corp-ci.com
# usharesoft.com
# anomali.com
# tresorit.com
# pixnet.tw
# monkeylearn.com
# digital.homeoffice.gov.uk
# ensc.de
# manateeworks.com
# solwit.com
# nexosis.com
# kimsq.com
# cloud.si
# kiwi.com
# jqwidgets.com
# spaceapplications.com
# netcentric.biz
# cyrusinnovation.com
# internavenue.com
# opsdisk.com
# ciandt.com
# parrot.com
# kpmg.nl
# indiegogo.com
# sugarcrm.com
# ucloud.cn
# solidstategroup.com
# lightstep.com
# wemakecustom.com
# codequest.com
# intercom.io
# autonomoustuff.com
# java.net
# fccn.pt
# fr.clara.net
# eiffel.com
# kilix.fr
# ideanotion.net
# leidos.com
# netbeast.co
# spinn3r.com
# linode.com
# biologie.ens.fr
# samfundet.no
# xsharp.eu
# machinalis.com
# canopytax.com
# hcuge.ch
# surycat.com
# electronoob.com
# yandex.com
# velir.com
# yunionyun.com
# comicrelief.com
# dreipol.ch
# ppi.de
# robotcaresystems.com
# techjoomla.com
# n11.com
# rooyekhat.co
# libelium.com
# company100.com
# paytm.com
# 3yourmind.com
# prestaconcept.net
# tmatesoft.com
# synapticon.com
# thinkgeo.com
# ua.pt
# vshn.ch
# yeecall.com
# compugraf.com.br
# zeoalliance.com
# mdaus.com
# eucalyptus.com
# kixeye.com
# gfz-potsdam.de
# bancor.network
# exposebox.com
# hanno.co
# equitania.com
# zimbra.com
# mni.thm.de
# fh-wels.at
# met.no
# alphanodes.com
# zinitsolutions.com
# fastmail.com
# textalk.se
# nexenio.com
# logicmonitor.com
# digitalglobe.com
# kasten.io
# techfak.uni-bielefeld.de
# skymizer.com
# pleasedontspam.me
# disney.com
# zlg.cn
# delmic.com
# stackhpc.com
# avsystem.com
# invitae.com
# cogniteev.com
# ing.nl
# drw.com
# guardian.co.uk
# worksolutions.ru
# stablekernel.com
# chumby.com
# betfair.com
# checkmarx.com
# efigence.com
# taykey.com
# taurus.ai
# ribose.com
# keen.io
# iteam.se
# securisec.com
# toptensoftware.com
# moneyforward.co.jp
# nieuwland.nl
# yaochufa.com
# n2sm.net
# redborder.com
# mandiant.com
# xebia.fr
# uolinc.com
# xenit.eu
# locusrobotics.com
# cloudesire.com
# omega-software.hr
# travelport.com
# payu.pl
# univ-lorraine.fr
# uruit.com
# sueddeutsche.de
# conversantmedia.com
# codeweavers.com
# crytek.de
# statoil.com
# resol.de
# device-insight.com
# mathias-kettner.de
# befox.fr
# renderedtext.com
# lin3s.com
# laser-group.com
# heysparkbox.com
# everit.biz
# obspm.fr
# haomo-studio.com
# kardex.com
# soluto.com
# shtrih-m.ru
# testobject.com
# coxauto.co.uk
# nuweb.com
# inova.si
# elasticbox.com
# gilt.com
# fgv.br
# arccn.ru
# getvero.com
# virtual.ufc.br
# homedepot.com
# active-bridge.com
# fit.vutbr.cz
# asymmetrik.com
# sqreamtech.com
# inf.ufrgs.br
# cdc.gov
# sraoss.co.jp
# zextras.com
# processmaker.com
# starrez.com
# scandit.com
# nerdwallet.com
# mango-solutions.com
# palmabit.com
# veritrans.co.id
# persistent.com
# tuxedocomputers.com
# picovoice.ai
# tsolucio.com
# lendup.com
# qoncept.co.jp
# wearefriday.com
# makeblock.cc
# butenko.me
# airbus.com
# mapspeople.com
# iparadigms.com
# libertymutual.com
# sendgrid.com
# chathamfinancial.com
# easyinnova.com
# fr.ibm.com
# geometryfactory.com
# anoda.mobi
# tobii.com
# msystechnologies.com
# runtastic.com
# corp.bluecherry.net
# lacunasoftware.com
# haruhichan.com
# braiins.cz
# pcloud.com
# rmn.com
# yetiforce.com
# squishymedia.com
# aist.go.jp
# esss.co
# sourcefire.com
# rongcapital.cn
# iot.bzh
# accso.de
# dsacademy.com.br
# mikamai.com
# marvell.com
# parsons.com
# itextpdf.com
# accruent.com
# vodori.com
# simprints.com
# quali.com
# atyantik.com
# ideasoncanvas.com
# opensupports.com
# concur.com
# nopnop.net
# transcriptic.com
# counterflowai.com
# keepworks.com
# deque.com
# fxcm.com
# netis.com.cn
# intelliants.com
# blocko.io
# mobica.com
# merixstudio.com
# flextrade.com
# fivium.co.uk
# thunisoft.com
# glencoesoftware.com
# juxt.pro
# schubergphilis.com
# raintank.io
# oddbird.net
# uco.es
# unknown.com
# magazino.eu
# stratoscale.com
# enspiral.com
# yotpo.com
# semtech.com
# alephobjects.com
# hirevue.com
# hacklab.com.br
# tildeslash.com
# john.mcfarlane.name
# issgreppi.it
# 99cloud.net
# xogrp.com
# luizalabs.com
# georgester.com
# qwant.com
# adelyte.com
# swisscom.com
# xpeppers.com
# zooz.com
# ilbers.de
# research.xbmail.com.cn
# wigle.net
# tacklind.com
# dtu.dk
# dealeron.com
# puzzlepart.com
# appsaloon.be
# sendpulse.com
# opusvl.com
# analysiscenter.ru
# khadas.com
# gradecam.com
# sternpunkt.at
# netcosports.com
# clio.com
# 1xinternet.de
# harrys.com
# atmel.com
# physik.hu-berlin.de
# wunder.io
# ga.gov.au
# geeks.ltd.uk
# webank.com
# lightrains.com
# ign.fr
# thisisnumero.com
# wearehathway.com
# serverless.com
# figure53.com
# artelnics.com
# credit.frontlinesms.com
# usherbrooke.ca
# imatia.com
# codeinside.ru
# donmccurdy.com
# elliemae.com
# mailcleaner.net
# binc.jp
# evolvingweb.ca
# juspay.in
# takipi.com
# payworks.com
# caphyon.com
# ubidots.com
# sonymobile.com
# phpboost.com
# pantheon.tech
# ku.th
# sela.co.il
# dome9.com
# openkm.com
# sensorberg.com
# gandi.net
# foobla.com
# vn.fujitsu.com
# mitocgroup.com
# woboq.com
# quoininc.com
# prolucid.ca
# fdm.uni-freiburg.de
# didotech.com
# microsemi.com
# magnetic.io
# europeana.eu
# bkjk.com
# engineyard.com
# starcounter.com
# clicktravel.com
# nextbeat.net
# intranda.com
# forter.com
# rodeofx.com
# duckduckgo.com
# lundegaard.eu
# gl-inet.com
# fir.im
# thehyve.nl
# plentymarkets.com
# univa.com
# univille.br
# gkmsoft.ru
# tulpep.com
# hitachi.com
# de.ibm.com
# dsr-company.com
# digineo.de
# magentys.io
# crowdin.com
# aimms.com
# oneall.com
# suyati.com
# hesaitech.com
# yangqianguan.com
# ableton.com
# biomed.ee.ethz.ch
# droptica.pl
# iwm.fraunhofer.de
# rei.com
# numberfour.eu
# bpteach.com
# yoozoo.com
# iterate.ch
# alkemics.com
# sourcerer.io
# wise2c.com
# hsr.ch
# asheavenue.com
# d-teknoloji.com.tr
# gruporbs.com.br
# emcraft.com
# blackpepper.co.uk
# xwiki.com
# databps.com
# ixsystems.com
# vitwit.com
# brandingbrand.com
# nextgen.com
# atguigu.com
# varian.com
# croud.co.uk
# yapstudios.com
# pingendo.com
# xamoom.com
# troopers.email
# hydrogenplatform.com
# thi.de
# ligadata.com
# indictranstech.com
# ustepper.com
# beeswax.com
# seagate.com
# bmc.com
# awakenetworks.com
# matrox.com
# iplas.com.cn
# univention.de
# mayvenn.com
# mtr-design.com
# coupang.com
# irit.fr
# raccoongang.com
# cityzendata.com
# wizishop.com
# yougov.de
# web-computing.de
# ucm.es
# kontakt.io
# mytaxi.com
# engys.com
# smartcodeltd.co.uk
# runtime-revolution.com
# ibi.com
# pony.ai
# crowdtap.com
# ionio.gr
# byndyusoft.com
# weidian.com
# airware.com
# shutterstock.com
# r3.com
# koanlogic.com
# yopeso.com
# ecmoban.com
# julius.fr
# sysdata.it
# pbsa.info
# ronasit.com
# sidn.nl
# etu.unige.ch
# thulium.pl
# ecsec.de
# etersoft.ru
# financialforce.com
# covenantsql.io
# dataminded.be
# riptideio.com
# pushwoosh.com
# mathildetech.com
# orbitz.com
# adfab.fr
# syseleven.de
# arealidea.ru
# civic.com
# opm.gov
# cubettech.com
# evopro-ag.de
# opsway.com
# opengis.ch
# joeharrison.com
# discoursehosting.com
# globo-tech.com
# ulaval.ca
# flyacts.com
# image-engine.com
# strava.com
# cesnet.cz
# dhtmlx.com
# mafengwo.com
# mirabeau.nl
# jayfields.com
# rsa.com
# splone.com
# shamanland.com
# pinpt.com
# axinom.com
# zello.com
# tradebyte.com
# terminallabs.com
# tesobe.com
# joinroot.com
# bsc-ideas.com
# adcubum.com
# schogini.com
# origin-trail.com
# brainhub.pl
# ipea.gov.br
# nutonomy.com
# vivowares.com
# radiasoft.net
# holmes.nl
# spaziodati.eu
# froglogic.com
# kano.me
# techmagic.co
# magmodules.eu
# freshdesk.com
# siili.com
# cultureamp.com
# anki.com
# ic.ufal.br
# coremedia.com
# kabisa.nl
# codus.com.br
# yahoo-corp.jp
# rhythmagency.com
# pivasoftware.com
# genialis.com
# plataformatec.com.br
# 2lemetry.com
# 5minds.de
# correlation-one.com
# reprappro.com
# leinao.ai
# imapp.pl
# alliedmods.net
# silvercurve.co.uk
# chinaums.com
# culqi.com
# holder.nl
# cl.uni-heidelberg.de
# novalab.io
# keensoft.es
# jenslody.de
# southbanksoftware.com
# fastvps.ru
# gdn-commerce.com
# whoknows.com
# apester.com
# gs.com
# versal.com
# applicaster.com
# asapp.com
# helmholtz-muenchen.de
# picoded.com
# vtech.fr
# applovin.com
# blobcity.com
# kodapan.se
# us.imshealth.com
# inovexcorp.com
# tellapart.com
# nulogy.com
# s2it.corp
# monetdbsolutions.com
# unleashnetworks.com
# avocarrot.com
# waavi.com
# conwet.com
# qudian.com
# ovoenergy.com
# steelseries.com
# twistedmatrix.com
# tophatmonocle.com
# lsexperts.de
# onemt.com.cn
# novaksolutions.com
# wanda.cn
# davd.eu
# campaignmonitor.com
# s2it.com.br
# prjkt.io
# okcoin.com
# cnes.fr
# cs.uni-potsdam.de
# wearefine.com
# cae.com
# imag.fr
# veritas.com
# onepercentclub.com
# elabs.se
# pik-potsdam.de
# mujin.co.jp
# xetus.com
# checkout.com
# payu.in
# qindel.com
# targetprocess.com
# mail.nih.gov
# realscout.com
# palm.com
# buzzvil.com
# smsapi.pl
# pl.abb.com
# fda.hhs.gov
# slickage.com
# outbrain.com
# mpdl.mpg.de
# barchart.com
# fast.ai
# whirl-i-gig.com
# wechall.net
# appfirst.com
# m3.com
# greenwaves-technologies.com
# evernote.com
# crobox.com
# blueeast.com
# imaginea.com
# tongdun.cn
# shiwaforce.com
# neos-it.de
# kaike.la
# pelagicore.com
# bleech.de
# yuppielabel.com
# xiaoyi.com
# opitz-consulting.com
# infrared5.com
# opus.ee
# eldersoss.com
# acaprojects.com
# furore.com
# qunhemail.com
# agfa.com
# priv.de
# openfin.co
# evernym.com
# somethingdigital.com
# frontiir.com
# zynx.com
# mikroe.com
# qualys.com
# jago-ag.cn
# marsbased.com
# appier.com
# telecomsante.com
# cs.uni-salzburg.at

# %%
# Faz o request na whoIs
nome_empresas = []
sim = nao = 0
for dominio in dominio_dominante:
    print(f"Analisando o dominio [{dominio}]")
    try:
        w = whois.whois(dominio)
        empresa = w["org"]
    except Exception as e:
        nome_empresas.append("NaN")
        print("-" * 10 + f"Falha na Análise: {e}")
        nao += 1
    else:
        if empresa is None:
            nome_empresas.append("NaN")
            print("-" * 10 + f"Falha na Análise")
            nao += 1
        else:
            nome_empresas.append(empresa)
            print("-" * 10 + "Analisado com Sucesso!")
            sim += 1
# Out:
# Analizando o dominio [scottlogic.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [object.net]
# ----------Falha na Análise
# Analizando o dominio [makina-corpus.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [travis-ci.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [paddle.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ladybirdweb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [fb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [w11k.de]
# ----------Falha na Análise
# Analizando o dominio [hrsoft.net]
# ----------Falha na Análise
# Analizando o dominio [0kn.sakura.ne.jp]
# ----------Falha na Análise: 'org'
# Analizando o dominio [technikum-wien.at]
# ----------Analizado com Sucesso!
# Analizando o dominio [lbry.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [wgen.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashicorp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [guidesmiths.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [process-one.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [twitter.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ebuinfo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uber.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [udacity.com]
# ----------Falha na Análise
# Analizando o dominio [elementary.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [elementary.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [grammatech.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codility.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tokbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [segment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cloudinary.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [plex.tv]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [replicated.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bah.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [stripe.com]
# ----------Falha na Análise
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [icalialabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [janestreet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tokbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [axosoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cartodb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [storj.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [icinga.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [netguru.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [corp.globo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mozilla.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [gigya-inc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [actionsky.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uber.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [automattic.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [oracle.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [adobe.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [roncoo.com]
# ----------Falha na Análise
# Analizando o dominio [syss.de]
# ----------Falha na Análise
# Analizando o dominio [synercomm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ironcorelabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [polidea.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [vincit.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [vmware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kunstmaan.be]
# ----------Analizado com Sucesso!
# Analizando o dominio [kartoza.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [b2wdigital.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cern.ch]
# ----------Falha na Análise: 'org'
# Analizando o dominio [500tech.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [timescale.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cozycloud.cc]
# ----------Falha na Análise
# Analizando o dominio [benmu-health.com]
# ----------Falha na Análise
# Analizando o dominio [forgerock.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [synadia.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [arm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jam3.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [realtimegenomics.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [usgs.gov]
# ----------Falha na Análise
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [unity3d.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [datacamp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [goalgorilla.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [idealo.de]
# ----------Falha na Análise
# Analizando o dominio [avira.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jfrog.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [matterhackers.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [databricks.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [recast.ai]
# ----------Falha na Análise
# Analizando o dominio [oslandia.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mnubo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nearform.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [confluent.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [devsu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tu-ilmenau.de]
# ----------Falha na Análise
# Analizando o dominio [blackducksoftware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [baidu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [agiliq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jidesoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [vmware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [brave.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mesosphere.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [clusterhq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [steamclock.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [chargebee.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [funkwerk-itk.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [leapmotion.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [latera.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [segment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [infinite.red]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sap.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [udacity.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [documize.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codacy.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bangthetable.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nokia.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mugo.ca]
# ----------Falha na Análise: 'org'
# Analizando o dominio [mailjet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [paymaxi.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ledger.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [elementary.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [udacity.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [neotechnology.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [emc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [goodeggs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [resin.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [solus-project.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cliqz.com]
# ----------Falha na Análise
# Analizando o dominio [grammarly.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tendermint.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashicorp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [linux.intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [2ndquadrant.it]
# ----------Falha na Análise: 'org'
# Analizando o dominio [palantir.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [baidu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [integer-net.de]
# ----------Falha na Análise
# Analizando o dominio [slack-corp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [thoughtworks.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rongcloud.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [telesign.com]
# ----------Falha na Análise
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [webgriffe.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [hasura.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [npmjs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tig.nl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [wso2.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cesanta.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [rongcloud.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [teambition.com]
# ----------Falha na Análise
# Analizando o dominio [hashicorp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mercadolibre.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [duallab.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [us.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [teambition.com]
# ----------Falha na Análise
# Analizando o dominio [corp.mail.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [launchdarkly.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [scality.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [maxmind.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [adobe.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [conffx.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tibco.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [corp.globo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pal-robotics.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [datadoghq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [voorhoede.nl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [appodeal.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tranquil.it]
# ----------Falha na Análise: 'org'
# Analizando o dominio [branch.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [reactiveops.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [maidsafe.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [marel.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [evojam.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pnnl.gov]
# ----------Falha na Análise
# Analizando o dominio [baidu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [criteo.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [yandex-team.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [twokings.nl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [playfab.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sinnerschrader.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [vaadin.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [medium.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [amd.com]
# ----------Falha na Análise
# Analizando o dominio [starlingbank.com]
# ----------Falha na Análise
# Analizando o dominio [intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [360.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [icon.foundation]
# ----------Analizado com Sucesso!
# Analizando o dominio [linuxacademy.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [helsinki.fi]
# ----------Falha na Análise: 'org'
# Analizando o dominio [unitedstack.com]
# ----------Falha na Análise
# Analizando o dominio [continuum.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [npmjs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [testdouble.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [udacity.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [clever.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [il.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [garmin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [imperva.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [unity3d.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [novoda.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [segment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [freshplanet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [duallab.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [formidable.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [parity.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [confluent.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [juliacomputing.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uipath.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [recast.ai]
# ----------Falha na Análise
# Analizando o dominio deb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rstudio.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [akveo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [couchbase.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [wso2.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ledger.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [arduino.cc]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Falha na Análise
# Analizando o dominio [janestreet.com]
# ----------Falha na Análise
# Analizando o dominio [fullcontact.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [luno.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hortonworks.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mirantis.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [taobao.com]
# ----------Falha na Análise
# Analizando o dominio [unity3d.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashrocket.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sri.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [goodeggs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [luxoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [usemarkup.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [dji.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [consensys.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [kunstmaan.be]
# ----------Analizado com Sucesso!
# Analizando o dominio [iit.demokritos.gr]
# ----------Falha na Análise
# Analizando o dominio [mixi.co.jp]
# ----------Falha na Análise: 'org'
# Analizando o dominio [torchbox.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [brave.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [qunar.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [zte.com.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [osi.ca.gov]
# ----------Falha na Análise
# Analizando o dominio [corp.globo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [transifex.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [consensys.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [us.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [yworks.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [shapelets.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ti.rwth-aachen.de]
# ----------Falha na Análise
# Analizando o dominio [pubnub.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jetbrains.com]
# ----------Falha na Análise
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [creditease.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [lge.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mirantis.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [merapar.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ncbi.nlm.nih.gov]
# ----------Falha na Análise
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [aptoide.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [isbx.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [trailofbits.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [circleci.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cern.ch]
# ----------Falha na Análise: 'org'
# Analizando o dominio [nebulas.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [go-jek.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nimbl3.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [rocket.chat]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [kickstarter.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [zte.com.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [status.im]
# ----------Falha na Análise
# Analizando o dominio [zendesk.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [parkingwang.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [wix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ufal.mff.cuni.cz]
# ----------Falha na Análise: Your connection limit exceeded. Please slow down and try again later.
#
# Analizando o dominio [twitter.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jiguang.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [axoniq.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uk.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [project-a.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mosek.com]
# ----------Falha na Análise
# Analizando o dominio [nadeo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ettus.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [netcetera.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [loomcom.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bitfury.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jarsa.com.mx]
# ----------Falha na Análise: 'org'
# Analizando o dominio [reactioncommerce.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [twobitlabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [massive.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [zevenet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [didichuxing.com]
# ----------Falha na Análise
# Analizando o dominio [twitter.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [messagebird.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [enthought.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rackspace.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [yahoo-inc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [acrobotic.com]
# ----------Falha na Análise
# Analizando o dominio [swimlane.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nylas.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [digital.cabinet-office.gov.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [devexpress.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sas.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nist.gov]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [inria.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [rwth-aachen.de]
# ----------Falha na Análise
# Analizando o dominio [sifive.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sim.tu-darmstadt.de]
# ----------Falha na Análise
# Analizando o dominio [xiaonongnv.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [alterego.biz.ua]
# ----------Falha na Análise: 'org'
# Analizando o dominio [adacore.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [maxpoint.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ericsson.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [credits.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hubspot.com]
# ----------Falha na Análise
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [creditease.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [replicated.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashicorp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mesosphere.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [bankex.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [yubico.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [docusign.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [claranet.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [mesosphere.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [counsyl.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [caelum.com.br]
# ----------Falha na Análise: 'org'
# Analizando o dominio [shoutem.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ti.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [corp.mail.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [npmjs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [swiftkick.it]
# ----------Falha na Análise: 'org'
# Analizando o dominio [enova.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [stripe.com]
# ----------Falha na Análise
# Analizando o dominio [nexb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [apicloud.com]
# ----------Falha na Análise
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [teradata.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [agiliq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codaxy.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [adacore.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [coder.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rapid7.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [iron.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [youzan.com]
# ----------Falha na Análise
# Analizando o dominio [rigetti.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [galeracluster.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashicorp.com]
# ----------Falha na Análise
# Analizando o dominio [sourcegraph.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [appfoundry.be]
# ----------Falha na Análise
# Analizando o dominio [beam-mw.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bedegaming.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [spiralscout.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [qt.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [wrld3d.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [illumina.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kilograpp.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [ravenbrook.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [devbridge.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cliqz.com]
# ----------Falha na Análise
# Analizando o dominio [stripe.com]
# ----------Falha na Análise
# Analizando o dominio [thecontrolgroup.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [twistlock.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [liferay.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [continuum.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [outlandish.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [fb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jamitlabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tencent.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [kingsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [yahoo-inc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [us.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sourcegraph.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [perimeterx.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [infor.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [gettyimages.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [inovex.de]
# ----------Falha na Análise
# Analizando o dominio [alibaba-inc.com]
# ----------Falha na Análise
# Analizando o dominio [travelping.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [qaware.de]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [iqmetrix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [linux.intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [llnl.gov]
# ----------Falha na Análise
# Analizando o dominio [mozilla.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [blackducksoftware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mercadolibre.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [seegno.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cumulusnetworks.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [squaredup.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [digitalocean.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [informatik.uni-hamburg.de]
# ----------Falha na Análise
# Analizando o dominio [mapbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [opennodecloud.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [joyent.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mapbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [onyxpoint.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [llnl.gov]
# ----------Falha na Análise
# Analizando o dominio [yonyou.com]
# ----------Falha na Análise
# Analizando o dominio [balsamiq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [magento.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [intel.com]
# ----------Falha na Análise
# Analizando o dominio [bitpay.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rocket.chat]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [iron.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [showmax.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [oreilly.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mirantis.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [linux.intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uber.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rancher.com]
# ----------Falha na Análise
# Analizando o dominio [fishtownanalytics.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mesosphere.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [parity.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [ustwo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [yandex-team.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [cisco.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rabbitmq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codecombat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [immunant.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [leapmotion.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [47deg.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [megvii.com]
# ----------Falha na Análise
# Analizando o dominio [rallydev.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [six-group.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [remobjects.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [highfidelity.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [47deg.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [qaware.de]
# ----------Falha na Análise
# Analizando o dominio [joyent.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [indeed.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [it-kartellet.dk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [mdsol.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cos.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [rozdoum.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [epam.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tryolabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [polysync.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [linuxdeepin.com]
# ----------Falha na Análise
# Analizando o dominio [elementary.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [mageplaza.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [znc.com.br]
# ----------Falha na Análise: 'org'
# Analizando o dominio [ettus.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hashicorp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [funkhaus.us]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tj-fintech.com]
# ----------Falha na Análise
# Analizando o dominio [mercadolibre.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [realm.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [passbolt.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [bbva.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [streamr.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [saul.pw]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [antfin.com]
# ----------Falha na Análise
# Analizando o dominio [catalyst-au.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [kitware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [calidae.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [icalialabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [consensys.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [numworks.com]
# ----------Falha na Análise
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ona.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [process-one.net]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [linux.intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [deligence.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [dstl.gov.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [iex.ec]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [spotify.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rokid.com]
# ----------Falha na Análise
# Analizando o dominio [aftership.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sap.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [framgia.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ushahidi.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [stelligent.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [twitter.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [shopex.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [schibsted.pl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [robotis.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [intel.com]
# ----------Falha na Análise
# Analizando o dominio [coronalabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [haulmont.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [trek10.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [solo.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [segment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [formidable.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sas.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kartoza.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tozny.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [remobjects.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [unif.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [dlg.im]
# ----------Falha na Análise
# Analizando o dominio [yandex-team.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [nccgroup.trust]
# Error trying to connect to socket: closing socket
# ----------Analizado com Sucesso!
# Analizando o dominio [sonarsource.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [10up.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [snipcart.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [opencraft.com]
# ----------Falha na Análise
# Analizando o dominio [castironcoding.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [helium.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uk.ibm.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codeship.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [thefuntasty.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [adobe.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mozilla.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [unic.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rgi-corp.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [extremenetworks.com]
# ----------Falha na Análise
# Analizando o dominio [roche.com]
# ----------Falha na Análise
# Analizando o dominio [affectiva.com]
# ----------Falha na Análise
# Analizando o dominio [fauna.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [atlassian.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [elastic.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [ihmc.us]
# ----------Falha na Análise: 'org'
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [mundipagg.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nist.gov]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [experius.nl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [stratumn.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ornl.gov]
# ----------Falha na Análise
# Analizando o dominio [nccgroup.trust]
# Error trying to connect to socket: closing socket
# ----------Analizado com Sucesso!
# Analizando o dominio [baidu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [xwp.co]
# ----------Falha na Análise
# Analizando o dominio [flatstack.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [gene.com]
# ----------Falha na Análise
# Analizando o dominio [railsware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [squareup.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jd.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [adobe.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [onlyoffice.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [lightcurve.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [nvidia.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [net-ng.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [marklogic.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [agriya.in]
# ----------Falha na Análise: 'org'
# Analizando o dominio [caffeina.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [alibaba-inc.com]
# ----------Falha na Análise
# Analizando o dominio [jiguang.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [portworx.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [intel.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [linkedin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [fastly.com]
# ----------Falha na Análise
# Analizando o dominio [marketlytics.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [resin.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [pearson.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [railsware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sunfounder.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [plot.ly]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hujiang.com]
# ----------Falha na Análise
# Analizando o dominio [mesosphere.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [ipgp.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [janestreet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [navercorp.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [yandex-team.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [ipb-halle.de]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [xamarin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [diennea.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [devexpress.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [onelogin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [touk.pl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [okfn.de]
# ----------Falha na Análise
# Analizando o dominio [namshi.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [postgrespro.ru]
# ----------Falha na Análise
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [starlingbank.com]
# ----------Falha na Análise
# Analizando o dominio [oracle.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [robotis.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [travis-ci.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [nicehash.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [eoc.ch]
# ----------Falha na Análise: 'org'
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [camunda.com]
# ----------Falha na Análise
# Analizando o dominio [omise.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [clever-cloud.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [fastly.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [codefresh.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [valor-software.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [circleci.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tencent.com]
# ----------Falha na Análise
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [pentaho.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [citrix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kitware.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [digital.cabinet-office.gov.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [testdouble.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [woorank.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [cerner.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [austincodingacademy.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pubnub.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pubnub.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [synadia.com]
# ...
# Analizando o dominio [pacificbiosciences.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ign.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [justcoded.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [algolia.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [opitz-consulting.com]
# ----------Falha na Análise
# Analizando o dominio [infrared5.com]
# ----------Falha na Análise
# Analizando o dominio [dnd.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [canonical.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [box.com]
# ----------Falha na Análise
# Analizando o dominio [baifendian.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [opus.ee]
# ----------Falha na Análise: 'org'
# Analizando o dominio [smile.fr]
# ----------Falha na Análise: 'org'
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [messagebird.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amd.com]
# ----------Falha na Análise
# Analizando o dominio [webfactory.de]
# ----------Falha na Análise
# Analizando o dominio [huawei.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [gsa.gov]
# ----------Falha na Análise
# Analizando o dominio [robotis.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [duosecurity.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mundipagg.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [fkie.fraunhofer.de]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [corp.globo.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [salesforce.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [meltwater.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [juliacomputing.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [janestreet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [lanl.gov]
# ----------Falha na Análise
# Analizando o dominio [grammarly.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [stratio.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [orange.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [quandl.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sap.com]
# ----------Falha na Análise
# Analizando o dominio [wire.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [eldersoss.com]
# ----------Falha na Análise
# Analizando o dominio [nuodb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [grafana.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [digitalsurgeons.com]
# ----------Falha na Análise
# Analizando o dominio [47deg.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [elao.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [auth0.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ambitenergy.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [autodesk.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [betterment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [clarifai.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [easypost.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [acaprojects.com]
# ----------Falha na Análise
# Analizando o dominio [cask.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [breadwallet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [livechatinc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [target.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [redhat.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mapbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [lightbend.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pagar.me]
# ----------Falha na Análise: 'org'
# Analizando o dominio [pusher.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [zalando.de]
# ----------Falha na Análise
# Analizando o dominio [furore.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [navercorp.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [linagora.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [lanl.gov]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [linuxdeepin.com]
# ----------Falha na Análise
# Analizando o dominio [consensys.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [devexpress.com]
# ----------Falha na Análise
# Analizando o dominio [amazon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [esri.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [continuum.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [dnanexus.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [squareup.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [everit.biz]
# ----------Falha na Análise: 'org'
# Analizando o dominio [carbonblack.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rocket.chat]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [salesforce.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sendbird.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [zalando.de]
# ----------Falha na Análise
# Analizando o dominio [vacuumlabs.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [instana.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bigswitch.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [openlabs.co.in]
# ----------Falha na Análise: 'org'
# Analizando o dominio [netflix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [frontside.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [pnnl.gov]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [amazon.com]
# ----------Falha na Análise
# Analizando o dominio [pubnub.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [ooyala.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [qunhemail.com]
# ----------Falha na Análise
# Analizando o dominio [travis-ci.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [agfa.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [mapd.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bitnami.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [baidu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [consensys.net]
# ----------Analizado com Sucesso!
# Analizando o dominio [maxmind.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mozilla.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [salesforce.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [segment.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [shopify.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mesosphere.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [priv.de]
# ----------Falha na Análise
# Analizando o dominio [ideablade.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kite.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [bbc.co.uk]
# ----------Falha na Análise: 'org'
# Analizando o dominio [moltin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mapbox.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [openfin.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [staff.weibo.com]
# ----------Falha na Análise
# Analizando o dominio [ez.no]
# ----------Falha na Análise: 'org'
# Analizando o dominio [teclib.com]
# ----------Falha na Análise
# Analizando o dominio [cos.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [evernym.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [usgs.gov]
# ----------Falha na Análise
# Analizando o dominio [appscode.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [twobitlabs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [realseriousgames.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [dynatrace.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [arista.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [softwareag.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jiguang.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [synapticon.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [typefox.io]
# ----------Falha na Análise: 'org'
# Analizando o dominio [netspi.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [rocket.chat]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [youzan.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [uber.com]
# ----------Falha na Análise
# Analizando o dominio [salesforce.com]
# ----------Falha na Análise
# Analizando o dominio [udacity.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [qiniu.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [agiliq.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [thoughtworks.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [smartthings.com]
# ----------Falha na Análise
# Analizando o dominio [gfz-potsdam.de]
# ----------Falha na Análise
# Analizando o dominio [somethingdigital.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Falha na Análise
# Analizando o dominio [linux.intel.com]
# ----------Falha na Análise
# Analizando o dominio [voorhoede.nl]
# ----------Falha na Análise: 'org'
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [baidu.com]
# ----------Falha na Análise
# Analizando o dominio [linux.intel.com]
# ----------Falha na Análise
# Analizando o dominio [antfin.com]
# ----------Falha na Análise
# Analizando o dominio [netflix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [npmjs.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mapbox.com]
# ----------Falha na Análise
# Analizando o dominio [starkandwayne.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [forio.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [juliacomputing.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [restlet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [alkacon.com]
# ----------Falha na Análise
# Analizando o dominio [crystalnix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [frontiir.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [siteorigin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [grafana.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [alfabank.ru]
# ----------Analizado com Sucesso!
# Analizando o dominio [lightbend.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [omise.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [hazelcast.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sap.com]
# ----------Falha na Análise
# Analizando o dominio [alibaba-inc.com]
# ----------Falha na Análise
# Analizando o dominio [rocket.chat]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [cultureamp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [zynx.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [alibaba-inc.com]
# ----------Falha na Análise
# Analizando o dominio [sonarsource.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [wrld3d.com]
# ----------Falha na Análise
# Analizando o dominio [synacor.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mikroe.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [megvii.com]
# ----------Falha na Análise
# Analizando o dominio [springload.co.nz]
# ----------Falha na Análise: 'org'
# Analizando o dominio [qualys.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [udacity.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [thoughtworks.com]
# ----------Falha na Análise
# Analizando o dominio [coxautoinc.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [dowjones.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [tencent.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [influxdb.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mendix.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [trailofbits.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [kunstmaan.be]
# ----------Analizado com Sucesso!
# Analizando o dominio [brave.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [sap.com]
# ----------Falha na Análise
# Analizando o dominio [cognifide.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [jetbrains.com]
# ----------Falha na Análise
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [synacor.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [novoda.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [pivotal.io]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise: 'org'
# Analizando o dominio [openfin.co]
# ----------Analizado com Sucesso!
# Analizando o dominio [jago-ag.cn]
# ----------Falha na Análise: 'org'
# Analizando o dominio [marsbased.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [hp.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [appier.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [transcriptic.com]
# Error trying to connect to socket: closing socket
# ----------Falha na Análise
# Analizando o dominio [xamarin.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [mailjet.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [microsoft.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [telecomsante.com]
# ----------Falha na Análise
# Analizando o dominio [google.com]
# ----------Analizado com Sucesso!
# Analizando o dominio [google.com]
# ----------Falha na Análise
# Analizando o dominio [rapid7.com]
# ----------Falha na Análise
# Analizando o dominio [zendesk.com]
# ----------Falha na Análise
# Analizando o dominio [cs.uni-salzburg.at]
# ----------Analizado com Sucesso!
# Analizando o dominio [neoway.com.br]
# ----------Falha na Análise: 'org'
# Analizando o dominio [adacore.com]
# ----------Analizado com Sucesso!

# %%
print(nome_empresas)
# Out:
# ['NaN', 'Microsoft Corporation', 'NaN', 'MAK CORP.', 'REDACTED FOR PRIVACY', 'Microsoft Corporation', 'Paddle.com Market Ltd', 'Ladybird Web Solution Pvt Ltd', 'Microsoft Corporation', 'Meta Platforms, Inc.', 'NaN', 'NaN', 'NaN', 'COLT Telecom Austria GmbH', 'NaN', 'Amplify Education, Inc.', 'HASHICORP, INC.', 'DCSL Guidesmiths', 'ProcessOne', 'Twitter, Inc.', 'Shanghai Ebuinfo Tech Co., Ltd.', 'Intel Corporation', 'Uber Technologies, Inc.', 'NaN', 'NaN', 'NaN', 'Microsoft Corporation', 'GrammaTech, Inc.', 'REDACTED FOR PRIVACY', 'Vonage America LLC', 'Domains By Proxy, LLC', 'Cloudinary Ltd.', 'Plex GmbH', 'Microsoft Corporation', 'Contact Privacy Inc. Customer 12411664304', 'Booz Allen Hamilton', 'NaN', 'Amazon Technologies, Inc.', 'NaN', 'Red Hat, Inc.', 'Calmecac', 'Jane Street Group, LLC', 'Vonage America LLC', 'Axosoft', 'CartoDB Inc', 'NaN', 'Icinga GmbH', 'Microsoft Corporation', 'NETGURU S.A.', '27.865.757/0001-02', 'Microsoft Corporation', 'NaN', 'NaN', 'Statutory Masking Enabled', 'REDACTED FOR PRIVACY', 'Uber Technologies, Inc.', 'Automattic, Inc.', 'Oracle Corporation', 'Adobe Inc.', 'NaN', 'NaN', 'Privacy service provided by Withheld for Privacy ehf', 'Contact Privacy Inc. Customer 124272428', 'Microsoft Corporation', 'REDACTED FOR PRIVACY', 'Whois Privacy Service', 'VMware, Inc.', 'CSC Corporate Domains, Inc.', 'Kartoza (Pty) Ltd', 'B2W COMPANHIA DIGITAL', 'NaN', '500Tech', 'Privacy service provided by Withheld for Privacy ehf', 'NaN', 'NaN', 'ForgeRock Ltd', 'Microsoft Corporation', 'REDACTED FOR PRIVACY', 'Microsoft Corporation', 'Whois Privacy - Com Laude', 'Jam3 Inc.', 'REDACTED FOR PRIVACY', 'NaN', 'NaN', 'Unity Technologies SF', 'DataCamp Inc.', 'REDACTED FOR PRIVACY', 'NaN', 'NortonLifeLock Inc', 'Domain Protection Services, Inc.', 'MatterHackers, Inc.', 'Whois Privacy Service', 'Microsoft Corporation', 'NaN', 'Oslandia', 'mnubo', 'NaN', 'Google LLC', 'NaN', 'Privacy service provided by Withheld for Privacy ehf', 'NaN', 'Black Duck Software', 'Beijing Baidu Netcom Science Technology Co., Ltd.', 'Red Hat, Inc.', 'Agiliq Info Solutions India Pvt Ltd', 'JIDE Software, Inc.', 'Microsoft Corporation', 'Google LLC', 'VMware, Inc.', 'Microsoft Corporation', 'Privacy service provided by Withheld for Privacy ehf', 'Mesosphere, Inc', 'Domains By Proxy, LLC', 'Contact Privacy Inc. Customer 0133240238', 'Microsoft Corporation', 'ChargeBee Inc.,', 'Funkwerk Systems GmbH', 'LEAP MOTION, INC.', 'Latera LLC', 'Domains By Proxy, LLC', 'Infinite Red, Inc', 'Amazon Technologies, Inc.', 'Statutory Masking Enabled', 'Udacity, Inc.', 'Documize Inc.', 'Whois Privacy Protection Service, Inc.', 'BANG THE TABLE', 'NOKIA CORPORATION', 'NaN', 'Mailjet SAS', 'none', 'NaN', 'NaN', 'Udacity, Inc.', 'Neo Technology', 'EMC Corporation', 'Good Eggs Inc.', 'NaN', 'Privacy service provided by Withheld for Privacy ehf', 'NaN', 'Grammarly, Inc.', 'Contact Privacy Inc. Customer 1248710700', 'HASHICORP, INC.', 'Intel Corporation', 'NaN', 'DNStination Inc.', 'Beijing Baidu Netcom Science Technology Co., Ltd.', 'NaN', 'Slack Technologies, Inc.', 'ThoughtWorks Inc.', 'NaN', 'NaN', 'Red Hat, Inc.', 'NaN', 'NaN', 'Whois Privacy Service', 'NaN', 'NaN', 'WSO2, Inc.', 'Google LLC', 'Domains By Proxy, LLC', 'NaN', 'NaN', 'NaN', 'HASHICORP, INC.', 'MercadoLibre Inc.', 'Statutory Masking Enabled', 'International Business Machines Corporation', 'NaN', 'MGL Mail.ru Internet Assets Limited', 'NaN', 'Bizanga Store', 'DATA REDACTED', 'Microsoft Corporation', 'Adobe Inc.', 'Proxy Protection LLC', 'Amazon Technologies, Inc.', 'Microsoft Corporation', 'Tibco', '27.865.757/0001-02', 'PAL ROBOTICS S.L', 'Redacted for Privacy Purposes', 'NaN', 'NaN', 'Microsoft Corporation', 'Microsoft Corporation', 'APPODEAL INC.', 'NaN', 'NaN', 'Whois Privacy Service', 'Microsoft Corporation', 'NaN', 'REDACTED FOR PRIVACY', 'NaN', 'REDACTED FOR PRIVACY', 'NaN', 'Beijing Baidu Netcom Science Technology Co., Ltd.', 'NaN', 'YANDEX, LLC.', 'NaN', 'Microsoft Corporation', 'Accenture Gl ...

# %%
# Salva os nomes em um arquivo txt
with open("company_names.txt", "w", encoding="utf-8") as arquivo:
    for nome in nome_empresas:
        arquivo.write(f"{nome}\n")

# %%
# Adiciona uma nova coluna com os nomes das empresas conseguidas
df2 = df.assign(company_name_whois = nome_empresas)
df2
# Out:
#                                                      url  project_id sdtc  \
# 0                   https://github.com/ScottLogic/finput    63242591    t
# 1      https://github.com/Azure/azure-mobile-apps-cor...    31676975    t
# 2             https://github.com/bridgedotnet/Frameworks    18049778    t
# 3      https://github.com/makinacorpus/django-templat...       42543    f
# 4                        https://github.com/travis-ci/gh     6355545    f
# ...                                                  ...         ...  ...
# 17247                    https://github.com/rapid7/godap    34255643    f
# 17248      https://github.com/zendesk/zendesk_apps_tools     2274288    t
# 17249             https://github.com/cksystemsgroup/scal     2242312    t
# 17250            https://github.com/NeowayLabs/neosearch    16777887    f
# 17251             https://github.com/AdaCore/bb-runtimes    70649594    t
#
#       mcpc mcve  star_number  commit_count  files     lines  pull_requests  \
# 0        t    t           16           313    NaN       NaN             56
# 1        t    t           29            53   78.0   33715.0             22
# 2        f    f           38           353  413.0   62237.0             39
# 3        t    t           48            30   12.0    2154.0              3
# 4        t    f           22           163   72.0   21376.0             19
# ...    ...  ...          ...           ...    ...       ...            ...
# 17247    t    t           15            85   52.0    3332.0             10
# 17248    f    f           43          1462   72.0    4144.0            253
# 17249    f    f          106           490  161.0   22417.0             15
# 17250    t    t           30           237  112.0  113160.0             19
# 17251    f    f           23           260  869.0  166203.0              6
#
#        ...        cik  fg500  sec10k sec20f                      project_name  \
# 0      ...        NaN    NaN     NaN    NaN                            finput
# 1      ...   789019.0      t       t      f  azure-mobile-apps-cordova-client
# 2      ...        NaN    NaN     NaN    NaN                        Frameworks
# 3      ...        NaN    NaN     NaN    NaN     django-templatetag-handlebars
# 4      ...        NaN    NaN     NaN    NaN                                gh
# ...    ...        ...    ...     ...    ...                               ...
# 17247  ...  1560327.0      f       t      f                             godap
# 17248  ...  1463172.0      f       t      f                zendesk_apps_tools
# 17249  ...        NaN    NaN     NaN    NaN                              scal
# 17250  ...        NaN    NaN     NaN    NaN                         neosearch
# 17251  ...        NaN    NaN     NaN    NaN                       bb-runtimes
#
#           owner_login           company_name  owner_company      license  \
# 0          scottlogic                    NaN            NaN          MIT
# 1               Azure  MICROSOFT CORPORATION            NaN   Apache-2.0
# 2        bridgedotnet                    NaN            NaN   Apache-2.0
# 3        makinacorpus                    NaN            NaN     LGPL-3.0
# 4           travis-ci                    NaN            NaN          MIT
# ...               ...                    ...            ...          ...
# 17247          rapid7           RAPID7, INC.            NaN          MIT
# 17248         zendesk          Zendesk, Inc.            NaN   Apache-2.0
# 17249  cksystemsgroup                    NaN            NaN  NOASSERTION
# 17250      NeowayLabs                    NaN            NaN          NaN
# 17251         AdaCore                    NaN            NaN  NOASSERTION
#
#            company_name_whois
# 0                         NaN
# 1       Microsoft Corporation
# 2                         NaN
# 3                   MAK CORP.
# 4        REDACTED FOR PRIVACY
# ...                       ...
# 17247                     NaN
# 17248                     NaN
# 17249  University of Salzburg
# 17250                     NaN
# 17251                 AdaCore
#
# [17252 rows x 28 columns]

# %%
# Gera uma tabela excel com a nova tabela
df2.to_excel("Tabela_Spinellis_whois.xlsx")

# %%
df2["company_name_whois"].describe()
# Out:
# count     17252
# unique     1166
# top         NaN
# freq       5814
# Name: company_name_whois, dtype: object

# %%
# Tabela com os Nulos corrigidos
df3 = pd.read_excel("Tabela_Spinellis_whois_1.xlsx")
df3
# Out:
#                                                      url  project_id sdtc  \
# 0                   https://github.com/ScottLogic/finput  63242591.0    t
# 1      https://github.com/Azure/azure-mobile-apps-cor...  31676975.0    t
# 2             https://github.com/bridgedotnet/Frameworks  18049778.0    t
# 3      https://github.com/makinacorpus/django-templat...     42543.0    f
# 4                        https://github.com/travis-ci/gh   6355545.0    f
# ...                                                  ...         ...  ...
# 17247                    https://github.com/rapid7/godap  34255643.0    f
# 17248      https://github.com/zendesk/zendesk_apps_tools   2274288.0    t
# 17249             https://github.com/cksystemsgroup/scal   2242312.0    t
# 17250            https://github.com/NeowayLabs/neosearch  16777887.0    f
# 17251             https://github.com/AdaCore/bb-runtimes  70649594.0    t
#
#       mcpc mcve  star_number  commit_count  files     lines  pull_requests  \
# 0        t    t         16.0         313.0    NaN       NaN           56.0
# 1        t    t         29.0          53.0   78.0   33715.0           22.0
# 2        f    f         38.0         353.0  413.0   62237.0           39.0
# 3        t    t         48.0          30.0   12.0    2154.0            3.0
# 4        t    f         22.0         163.0   72.0   21376.0           19.0
# ...    ...  ...          ...           ...    ...       ...            ...
# 17247    t    t         15.0          85.0   52.0    3332.0           10.0
# 17248    f    f         43.0        1462.0   72.0    4144.0          253.0
# 17249    f    f        106.0         490.0  161.0   22417.0           15.0
# 17250    t    t         30.0         237.0  112.0  113160.0           19.0
# 17251    f    f         23.0         260.0  869.0  166203.0            6.0
#
#        ...        cik  fg500  sec10k sec20f                      project_name  \
# 0      ...        NaN    NaN     NaN    NaN                            finput
# 1      ...   789019.0      t       t      f  azure-mobile-apps-cordova-client
# 2      ...        NaN    NaN     NaN    NaN                        Frameworks
# 3      ...        NaN    NaN     NaN    NaN     django-templatetag-handlebars
# 4      ...        NaN    NaN     NaN    NaN                                gh
# ...    ...        ...    ...     ...    ...                               ...
# 17247  ...  1560327.0      f       t      f                             godap
# 17248  ...  1463172.0      f       t      f                zendesk_apps_tools
# 17249  ...        NaN    NaN     NaN    NaN                              scal
# 17250  ...        NaN    NaN     NaN    NaN                         neosearch
# 17251  ...        NaN    NaN     NaN    NaN                       bb-runtimes
#
#           owner_login           company_name  owner_company      license  \
# 0          scottlogic                    NaN            NaN          MIT
# 1               Azure  MICROSOFT CORPORATION            NaN   Apache-2.0
# 2        bridgedotnet                    NaN            NaN   Apache-2.0
# 3        makinacorpus                    NaN            NaN     LGPL-3.0
# 4           travis-ci                    NaN            NaN          MIT
# ...               ...                    ...            ...          ...
# 17247          rapid7           RAPID7, INC.            NaN          MIT
# 17248         zendesk          Zendesk, Inc.            NaN   Apache-2.0
# 17249  cksystemsgroup                    NaN            NaN  NOASSERTION
# 17250      NeowayLabs                    NaN            NaN          NaN
# 17251         AdaCore                    NaN            NaN  NOASSERTION
#
#            company_name_whois
# 0                         NaN
# 1       MICROSOFT CORPORATION
# 2                         NaN
# 3                   MAK CORP.
# 4        REDACTED FOR PRIVACY
# ...                       ...
# 17247                     NaN
# 17248                     NaN
# 17249  University of Salzburg
# 17250                     NaN
# 17251                 AdaCore
#
# [17252 rows x 28 columns]

# %%
# Um total de 11.438 não são nulos
df3["company_name_whois"].info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_137060/3375923659.py in <module>
#       1 # Um total de 11.438 não são nulos
# ----> 2 df3["company_name_whois"].info()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
# Cria uma nova coluna com com os dados da coluna company_name e company_name_whois
df3["Company_name_and_whois"] = ""

# %%
# company_name = df3["company_name"]
# company_name_whois = df3["company_name_whois"]

# for i, nome in company_name:
#     if pd.isna(nome):
#         df.at(i, "Company_name_and_whois") = df["company_name_whois"][i]
#     else:
#         df.at(i, "Company_name_and_whois") = df["Company_name"][i]

# %%
df3
# Out:
#                                                      url  project_id sdtc  \
# 0                   https://github.com/ScottLogic/finput  63242591.0    t
# 1      https://github.com/Azure/azure-mobile-apps-cor...  31676975.0    t
# 2             https://github.com/bridgedotnet/Frameworks  18049778.0    t
# 3      https://github.com/makinacorpus/django-templat...     42543.0    f
# 4                        https://github.com/travis-ci/gh   6355545.0    f
# ...                                                  ...         ...  ...
# 17247                    https://github.com/rapid7/godap  34255643.0    f
# 17248      https://github.com/zendesk/zendesk_apps_tools   2274288.0    t
# 17249             https://github.com/cksystemsgroup/scal   2242312.0    t
# 17250            https://github.com/NeowayLabs/neosearch  16777887.0    f
# 17251             https://github.com/AdaCore/bb-runtimes  70649594.0    t
#
#       mcpc mcve  star_number  commit_count  files     lines  pull_requests  \
# 0        t    t         16.0         313.0    NaN       NaN           56.0
# 1        t    t         29.0          53.0   78.0   33715.0           22.0
# 2        f    f         38.0         353.0  413.0   62237.0           39.0
# 3        t    t         48.0          30.0   12.0    2154.0            3.0
# 4        t    f         22.0         163.0   72.0   21376.0           19.0
# ...    ...  ...          ...           ...    ...       ...            ...
# 17247    t    t         15.0          85.0   52.0    3332.0           10.0
# 17248    f    f         43.0        1462.0   72.0    4144.0          253.0
# 17249    f    f        106.0         490.0  161.0   22417.0           15.0
# 17250    t    t         30.0         237.0  112.0  113160.0           19.0
# 17251    f    f         23.0         260.0  869.0  166203.0            6.0
#
#        ... fg500  sec10k  sec20f                      project_name  \
# 0      ...   NaN     NaN     NaN                            finput
# 1      ...     t       t       f  azure-mobile-apps-cordova-client
# 2      ...   NaN     NaN     NaN                        Frameworks
# 3      ...   NaN     NaN     NaN     django-templatetag-handlebars
# 4      ...   NaN     NaN     NaN                                gh
# ...    ...   ...     ...     ...                               ...
# 17247  ...     f       t       f                             godap
# 17248  ...     f       t       f                zendesk_apps_tools
# 17249  ...   NaN     NaN     NaN                              scal
# 17250  ...   NaN     NaN     NaN                         neosearch
# 17251  ...   NaN     NaN     NaN                       bb-runtimes
#
#           owner_login           company_name  owner_company      license  \
# 0          scottlogic                    NaN            NaN          MIT
# 1               Azure  MICROSOFT CORPORATION            NaN   Apache-2.0
# 2        bridgedotnet                    NaN            NaN   Apache-2.0
# 3        makinacorpus                    NaN            NaN     LGPL-3.0
# 4           travis-ci                    NaN            NaN          MIT
# ...               ...                    ...            ...          ...
# 17247          rapid7           RAPID7, INC.            NaN          MIT
# 17248         zendesk          Zendesk, Inc.            NaN   Apache-2.0
# 17249  cksystemsgroup                    NaN            NaN  NOASSERTION
# 17250      NeowayLabs                    NaN            NaN          NaN
# 17251         AdaCore                    NaN            NaN  NOASSERTION
#
#            company_name_whois Company_name_and_whois
# 0                         NaN
# 1       MICROSOFT CORPORATION
# 2                         NaN
# 3                   MAK CORP.
# 4        REDACTED FOR PRIVACY
# ...                       ...                    ...
# 17247                     NaN
# 17248                     NaN
# 17249  University of Salzburg
# 17250                     NaN
# 17251                 AdaCore
#
# [17252 rows x 29 columns]
